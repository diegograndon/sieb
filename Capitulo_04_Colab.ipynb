# %% [markdown]
# <a href="https://colab.research.google.com/github/diegograndon/sieb/blob/main/Capitulo_04_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# You can order print and ebook versions of *Think Python 3e* from
# [Bookshop.org](https://bookshop.org/a/98697/9781098155438) and
# [Amazon](https://www.amazon.com/_/dp/1098155432?smid=ATVPDKIKX0DER&_encoding=UTF8&tag=oreilly20-20&_encoding=UTF8&tag=greenteapre01-20&linkCode=ur2&linkId=e2a529f94920295d27ec8a06e757dc7c&camp=1789&creative=9325).

# %%
from os.path import basename, exists

def download(url):
    filename = basename(url)
    if not exists(filename):
        from urllib.request import urlretrieve

        local, _ = urlretrieve(url, filename)
        print("Downloaded " + str(local))
    return filename

download('https://github.com/AllenDowney/ThinkPython/raw/v3/thinkpython.py');
download('https://github.com/AllenDowney/ThinkPython/raw/v3/diagram.py');
download('https://github.com/ramalho/jupyturtle/releases/download/2024-03/jupyturtle.py');
# Out:
# Downloaded thinkpython.py
# Downloaded diagram.py
# Downloaded jupyturtle.py

# %%
import thinkpython

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Functions and Interfaces
#
# This chapter introduces a module called `jupyturtle`, which allows you to create simple drawings by giving instructions to an imaginary turtle.
# We will use this module to write functions that draw squares, polygons, and circles -- and to demonstrate **interface design**, which is a way of designing functions that work together.

# %% [markdown]
# ## The jupyturtle module
#
# To use the `jupyturtle` module, we can import it like this.

# %%
import jupyturtle

# %% [markdown]
# Now we can use the functions defined in the module, like `make_turtle` and `forward`.

# %%
jupyturtle.make_turtle()
jupyturtle.forward(100)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="250.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,250.0,75.0) translate(250.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# `make_turtle` creates a **canvas**, which is a space on the screen where we can draw, and a turtle, which is represented by a circular shell and a triangular head.
# The circle shows the location of the turtle and the triangle indicates the direction it is facing.
#
# `forward` moves the turtle a given distance in the direction it's facing, drawing a line segment along the way.
# The distance is in arbitrary units -- the actual size depends on your computer's screen.
#
# We will use functions defined in the `jupyturtle` module many times, so it would be nice if we did not have to write the name of the module every time.
# That's possible if we import the module like this.

# %%
from jupyturtle import make_turtle, forward

# %% [markdown]
# This version of the import statement imports `make_turtle` and `forward` from the `jupyturtle` module so we can call them like this.

# %%
make_turtle()
forward(100)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="250.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,250.0,75.0) translate(250.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# `jupyturtle` provides two other functions we'll use, called `left` and `right`.
# We'll import them like this.

# %%
from jupyturtle import left, right

# %% [markdown]
# `left` causes the turtle to turn left. It takes one argument, which is the angle of the turn in degrees.
# For example, we can make a 90 degree left turn like this.

# %%
make_turtle()
forward(100)
left(60)
forward(60)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="250.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="250.0" y1="75.0" x2="280.0" y2="23.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(210.0,280.0,23.0) translate(280.0, 23.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# This program moves the turtle east and then north, leaving two line segments behind.
# Before you go on, see if you can modify the previous program to make a square.

# %% [markdown]
# ## Making a square
#
# Here's one way to make a square.

# %%
make_turtle()

forward(40)
left(90)

forward(40)
left(90)

forward(40)
left(90)

forward(40)
left(90)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="190.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="190.0" y1="75.0" x2="190.0" y2="35.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="190.0" y1="35.0" x2="150.0" y2="35.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="35.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# Because this program repeats the same pair of lines four times, we can do the same thing more concisely with a `for` loop.

# %%
make_turtle()
for n in range(4):
  forward(40)
  right(90)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="190.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="190.0" y1="75.0" x2="190.0" y2="115.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="190.0" y1="115.0" x2="150.0" y2="115.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="115.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ## Encapsulation and generalization
#
# Let's take the square-drawing code from the previous section and put it in a function called `square`.

# %%
def square():
  for n in range(4):
    forward(40)
    right(90)

# %% [markdown]
# Now we can call the function like this.

# %%
make_turtle()
square()
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="190.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="190.0" y1="75.0" x2="190.0" y2="115.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="190.0" y1="115.0" x2="150.0" y2="115.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="115.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# Wrapping a piece of code up in a function is called **encapsulation**.
# One of the benefits of encapsulation is that it attaches a name to the code, which serves as a kind of documentation. Another advantage is that if you re-use the code, it is more concise to call a function twice than to copy and paste the body!
#
# In the current version, the size of the square is always `50`.
# If we want to draw squares with different sizes, we can take the length of the sides as a parameter.

# %%
def square(length):
  for n in range(4):
    forward(length)
    right(90)

# %% [markdown]
# Now we can draw squares with different sizes.

# %%
make_turtle()
square(20)
square(35)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="170.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="170.0" y1="75.0" x2="170.0" y2="95.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="170.0" y1="95.0" x2="150.0" y2="95.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="95.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="185.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="185.0" y1="75.0" x2="185.0" y2="110.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="185.0" y1="110.0" x2="150.0" y2="110.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="110.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# Adding a parameter to a function is called **generalization** because it makes the function more general: with the previous version, the square is always the same size; with this version it can be any size.
#
# If we add another parameter, we can make it even more general.
# The following function draws regular polygons with a given number of sides.

# %%
def polign(n, length):
    angulo = 360 / n
    for i in range(n):
        forward(length)
        left(angulo)

# %% [markdown]
# In a regular polygon with `n` sides, the angle between adjacent sides is `360 / n` degrees.
#
# The following example draws a `7`-sided polygon with side length `30`.

# %%
make_turtle()
polign(9, 20)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="170.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="170.0" y1="75.0" x2="185.3" y2="62.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="185.3" y1="62.1" x2="188.8" y2="42.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="188.8" y1="42.4" x2="178.8" y2="25.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="178.8" y1="25.1" x2="160.0" y2="18.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="160.0" y1="18.3" x2="141.2" y2="25.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="141.2" y1="25.1" x2="131.2" y2="42.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="131.2" y1="42.4" x2="134.7" y2="62.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="134.7" y1="62.1" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# When a function has more than a few numeric arguments, it is easy to forget what they are, or what order they should be in.
# It can be a good idea to include the names of the parameters in the argument list.

# %%
make_turtle()
polign(n=9, length=20)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="170.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="170.0" y1="75.0" x2="185.3" y2="62.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="185.3" y1="62.1" x2="188.8" y2="42.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="188.8" y1="42.4" x2="178.8" y2="25.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="178.8" y1="25.1" x2="160.0" y2="18.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="160.0" y1="18.3" x2="141.2" y2="25.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="141.2" y1="25.1" x2="131.2" y2="42.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="131.2" y1="42.4" x2="134.7" y2="62.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="134.7" y1="62.1" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# These are sometimes called "named arguments" because they include the parameter names.
# But in Python they are more often called **keyword arguments** (not to be confused with Python keywords like `for` and `def`).
#
# This use of the assignment operator, `=`, is a reminder about how arguments and parameters work -- when you call a function, the arguments are assigned to the parameters.

# %%
#PREGUNTAS DE EVALUACIÓN DIA LUNES 19/05
#¿Cuál es la diferencia entre llamar a jupyturtle.forward(100) y forward(100)? ¿Qué instrucción de Python permite esta diferencia?
#RESPUESTA→ No hay ninguna diferencia, en terminos de la tarea que realizan. Para "igualar" jupyturtle.forward(100) a forward(100), se debe importar la funcion "forward" directamente desde el modulo "jupyterturle" (from jupyterturtle import forward).

#Si quisieras dibujar un triángulo equilátero, ¿qué ángulo usarías en la función left()? Explica por qué.
#RESPUESTA→ Deberia utilizar 120, debido a que cada angulo externo debe ser igual a 120 para dar una suma equivalente de 360° en los angulos externos. Ejemplo de Aplicaión:
make_turtle()
def triang_equi(length):
  for i in range(3):
        forward(length)
        left(120)
triang_equi(60)

#Escribe el código para dibujar un hexágono regular usando un bucle for.
make_turtle()
def hex(length):
  for i in range(6):
    forward(length)
    left(60)
hex(40)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="210.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="210.0" y1="75.0" x2="180.0" y2="23.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.0" y1="23.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="190.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="190.0" y1="75.0" x2="210.0" y2="40.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="210.0" y1="40.4" x2="190.0" y2="5.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="190.0" y1="5.7" x2="150.0" y2="5.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="5.7" x2="130.0" y2="40.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="130.0" y1="40.4" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ## Approximating a circle
#
# Now suppose we want to draw a circle.
# We can do that, approximately, by drawing a polygon with a large number of sides, so each side is small enough that it's hard to see.
# Here is a function that uses `polygon` to draw a `30`-sided polygon that approximates a circle.

# %%
import math

def circle(radio):
    circumference = 2 * math.pi * radio
    n = 30
    length = circumference / n
    polign(n, length)

# %% [markdown]
# `circle` takes the radius of the the circle as a parameter.
# It computes `circumference`, which is the circumference of a circle with the given radius.
# `n` is the number of sides, so `circumference / n` is the length of each side.
#
# This function might take a long time to run.
# We can speed it up by calling `make_turtle` with a keyword argument called `delay` that sets the time, in seconds, the turtle waits after each step.
# The default value is `0.2` seconds -- if we set it to `0.02` it runs about 10 times faster.

# %%
make_turtle(delay=0.02)
circle(30)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="156.3" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="156.3" y1="75.0" x2="162.4" y2="73.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.4" y1="73.7" x2="168.2" y2="71.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="168.2" y1="71.1" x2="173.3" y2="67.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="173.3" y1="67.4" x2="177.5" y2="62.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="177.5" y1="62.8" x2="180.6" y2="57.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.6" y1="57.3" x2="182.5" y2="51.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="182.5" y1="51.4" x2="183.2" y2="45.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="183.2" y1="45.1" x2="182.5" y2="38.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="182.5" y1="38.9" x2="180.6" y2="32.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.6" y1="32.9" x2="177.5" y2="27.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="177.5" y1="27.4" x2="173.3" y2="22.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="173.3" y1="22.8" x2="168.2" y2="19.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="168.2" y1="19.1" x2="162.4" y2="16.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.4" y1="16.5" x2="156.3" y2="15.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="156.3" y1="15.2" x2="150.0" y2="15.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="15.2" x2="143.9" y2="16.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="143.9" y1="16.5" x2="138.1" y2="19.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="138.1" y1="19.1" x2="133.0" y2="22.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="133.0" y1="22.8" x2="128.8" y2="27.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="128.8" y1="27.4" x2="125.7" y2="32.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="125.7" y1="32.9" x2="123.7" y2="38.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="123.7" y1="38.9" x2="123.1" y2="45.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="123.1" y1="45.1" x2="123.7" y2="51.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="123.7" y1="51.4" x2="125.7" y2="57.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="125.7" y1="57.3" x2="128.8" y2="62.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="128.8" y1="62.8" x2="133.0" y2="67.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="133.0" y1="67.4" x2="138.1" y2="71.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="138.1" y1="71.1" x2="143.9" y2="73.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="143.9" y1="73.7" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# A limitation of this solution is that `n` is a constant, which means
# that for very big circles, the sides are too long, and for small
# circles, we waste time drawing very short sides.
# One option is to generalize the function by taking `n` as a parameter.
# But let's keep it simple for now.

# %% [markdown]
# ## Refactoring
#
# Now let's write a more general version of `circle`, called `arc`, that takes a second parameter, `angle`, and draws an arc of a circle that spans the given angle.
# For example, if `angle` is `360` degrees, it draws a complete circle. If `angle` is `180` degrees, it draws a half circle.
#
# To write `circle`, we were able to reuse `polygon`, because a many-sided polygon is a good approximation of a circle.
# But we can't use `polygon` to write `arc`.
#
# Instead, we'll create the more general version of `polygon`, called `polyline`.

# %%
def polign2(n, length, angle):
    for i in range(n):
        forward(length)
        left(angle)

# %% [markdown]
# `polyline` takes as parameters the number of line segments to draw, `n`, the length of the segments, `length`, and the angle between them, `angle`.
#
# Now we can rewrite `polygon` to use `polyline`.

# %%
def polygon(n, length):
    angle = 360.0 / n
    polign2(n, length, angle)

# %% [markdown]
# And we can use `polyline` to write `arc`.

# %%
def arc(radius, angle):
    arc_length = 2 * math.pi * radius * angle / 360
    n = 30
    length = arc_length / n
    step_angle = angle / n
    polign2(n, length, step_angle)

# %% [markdown]
# `arc` is similar to `circle`, except that it computes `arc_length`, which is a fraction of the circumference of a circle.
#
# Finally, we can rewrite `circle` to use `arc`.

# %%
def circle(radius):
    arc(radius,  360)

# %% [markdown]
# To check that these functions work as expected, we'll use them to draw something like a snail.
# With `delay=0`, the turtle runs as fast as possible.

# %%
make_turtle(delay=0)
polign(n=20, length=9)
arc(radius=70, angle=70)
circle(radius=10)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="159.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="159.0" y1="75.0" x2="167.6" y2="72.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="167.6" y1="72.2" x2="174.8" y2="66.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="174.8" y1="66.9" x2="180.1" y2="59.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.1" y1="59.6" x2="182.9" y2="51.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="182.9" y1="51.1" x2="182.9" y2="42.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="182.9" y1="42.1" x2="180.1" y2="33.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.1" y1="33.5" x2="174.8" y2="26.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="174.8" y1="26.2" x2="167.6" y2="21.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="167.6" y1="21.0" x2="159.0" y2="18.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="159.0" y1="18.2" x2="150.0" y2="18.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="18.2" x2="141.4" y2="21.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="141.4" y1="21.0" x2="134.2" y2="26.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="134.2" y1="26.2" x2="128.9" y2="33.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="128.9" y1="33.5" x2="126.1" y2="42.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="126.1" y1="42.1" x2="126.1" y2="51.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="126.1" y1="51.1" x2="128.9" y2="59.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="128.9" y1="59.6" x2="134.2" y2="66.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="134.2" y1="66.9" x2="141.4" y2="72.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="141.4" y1="72.2" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="152.9" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="152.9" y1="75.0" x2="155.7" y2="74.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="155.7" y1="74.9" x2="158.5" y2="74.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="158.5" y1="74.7" x2="161.4" y2="74.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="161.4" y1="74.3" x2="164.2" y2="73.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="164.2" y1="73.8" x2="167.0" y2="73.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="167.0" y1="73.3" x2="169.7" y2="72.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="169.7" y1="72.6" x2="172.5" y2="71.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="172.5" y1="71.8" x2="175.2" y2="70.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="175.2" y1="70.9" x2="177.8" y2="69.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="177.8" y1="69.8" x2="180.5" y2="68.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.5" y1="68.7" x2="183.0" y2="67.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="183.0" y1="67.5" x2="185.5" y2="66.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="185.5" y1="66.1" x2="188.0" y2="64.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="188.0" y1="64.7" x2="190.4" y2="63.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="190.4" y1="63.2" x2="192.7" y2="61.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="192.7" y1="61.5" x2="195.0" y2="59.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="195.0" y1="59.8" x2="197.2" y2="58.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="197.2" y1="58.0" x2="199.3" y2="56.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="199.3" y1="56.1" x2="201.4" y2="54.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="201.4" y1="54.1" x2="203.3" y2="52.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="203.3" y1="52.0" x2="205.2" y2="49.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="205.2" y1="49.9" x2="207.0" y2="47.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="207.0" y1="47.6" x2="208.7" y2="45.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="208.7" y1="45.3" x2="210.2" y2="43.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="210.2" y1="43.0" x2="211.7" y2="40.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="211.7" y1="40.5" x2="213.1" y2="38.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="213.1" y1="38.1" x2="214.4" y2="35.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="214.4" y1="35.5" x2="215.6" y2="32.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="215.6" y1="32.9" x2="216.7" y2="30.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="216.7" y1="30.3" x2="217.4" y2="28.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="217.4" y1="28.3" x2="217.7" y2="26.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="217.7" y1="26.2" x2="217.6" y2="24.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="217.6" y1="24.2" x2="217.0" y2="22.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="217.0" y1="22.1" x2="216.0" y2="20.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="216.0" y1="20.3" x2="214.7" y2="18.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="214.7" y1="18.7" x2="213.0" y2="17.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="213.0" y1="17.4" x2="211.1" y2="16.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="211.1" y1="16.5" x2="209.1" y2="16.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="209.1" y1="16.0" x2="207.0" y2="15.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="207.0" y1="15.9" x2="204.9" y2="16.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="204.9" y1="16.3" x2="203.0" y2="17.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="203.0" y1="17.0" x2="201.3" y2="18.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="201.3" y1="18.2" x2="199.8" y2="19.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="199.8" y1="19.7" x2="198.7" y2="21.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="198.7" y1="21.5" x2="198.0" y2="23.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="198.0" y1="23.5" x2="197.7" y2="25.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="197.7" y1="25.5" x2="197.8" y2="27.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="197.8" y1="27.6" x2="198.4" y2="29.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="198.4" y1="29.6" x2="199.4" y2="31.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="199.4" y1="31.5" x2="200.7" y2="33.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.7" y1="33.1" x2="202.4" y2="34.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="202.4" y1="34.4" x2="204.3" y2="35.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="204.3" y1="35.3" x2="206.3" y2="35.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="206.3" y1="35.8" x2="208.4" y2="35.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="208.4" y1="35.9" x2="210.5" y2="35.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="210.5" y1="35.5" x2="212.4" y2="34.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="212.4" y1="34.7" x2="214.1" y2="33.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="214.1" y1="33.6" x2="215.6" y2="32.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="215.6" y1="32.1" x2="216.7" y2="30.3"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(200.0,216.7,30.3) translate(216.7, 30.3)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# In this example, we started with working code and reorganized it with different functions.
# Changes like this, which improve the code without changing its behavior, are called **refactoring**.
#
# If we had planned ahead, we might have written `polyline` first and avoided refactoring, but often you don't know enough at the beginning of a project to design all the functions.
# Once you start coding, you understand the problem better.
# Sometimes refactoring is a sign that you have learned something.

# %% [markdown]
# ## Stack diagram
#
# When we call `circle`, it calls `arc`, which calls `polyline`.
# We can use a stack diagram to show this sequence of function calls and the parameters for each one.

# %%
from diagram import make_binding, make_frame, Frame, Stack

frame1 = make_frame(dict(radius=30), name='circle', loc='left')

frame2 = make_frame(dict(radius=30, angle=360), name='arc', loc='left', dx=1.1)

frame3 = make_frame(dict(n=60, length=3.04, angle=5.8),
                    name='polyline', loc='left', dx=1.1, offsetx=-0.27)

stack = Stack([frame1, frame2, frame3], dy=-0.4)

# %%
from diagram import diagram, adjust

width, height, x, y = [3.58, 1.31, 0.98, 1.06]
ax = diagram(width, height)
bbox = stack.draw(ax, x, y)
#adjust(x, y, bbox)

# %% [markdown]
# Notice that the value of `angle` in `polyline` is different from the value of `angle` in `arc`.
# Parameters are local, which means you can use the same parameter name in different functions; it's a different variable in each function, and it can refer to a different value.

# %% [markdown]
# ## A development plan
#
# A **development plan** is a process for writing programs.
# The process we used in this chapter is "encapsulation and generalization".
# The steps of this process are:
#
# 1.  Start by writing a small program with no function definitions.
#
# 2.  Once you get the program working, identify a coherent piece of it,
#     encapsulate the piece in a function and give it a name.
#
# 3.  Generalize the function by adding appropriate parameters.
#
# 4.  Repeat Steps 1 to 3 until you have a set of working functions.
#
# 5.  Look for opportunities to improve the program by refactoring. For
#     example, if you have similar code in several places, consider
#     factoring it into an appropriately general function.
#
# This process has some drawbacks -- we will see alternatives later -- but it can be useful if you don't know ahead of time how to divide the program into functions.
# This approach lets you design as you go along.

# %% [markdown]
# The design of a function has two parts:
#
# * The **interface** is how the function is used, including its name, the parameters it takes and what the function is supposed to do.
#
# * The **implementation** is how the function does what it's supposed to do.
#
# For example, here's the first version of `circle` we wrote, which uses `polygon`.

# %%
def circle(radius):
    circumference = 2 * math.pi * radius
    n = 30
    length = circumference / n
    polygon(n, length)

# %% [markdown]
# And here's the refactored version that uses `arc`.

# %%
def circle(radius):
    arc(radius,  360)

# %% [markdown]
# These two functions have the same interface -- they take the same parameters and do the same thing -- but they have different implementations.

# %% [markdown]
# ## Docstrings
#
# A **docstring** is a string at the beginning of a function that explains the interface ("doc" is short for "documentation").
# Here is an example:

# %%
def polign2(n, length, angle):
    """Draws line segments with the given length and angle between them.

    n: integer number of line segments
    length: length of the line segments
    angle: angle between segments (in degrees)
    """
    for i in range(n):
        forward(length)
        left(angle)

# %% [markdown]
# By convention, docstrings are triple-quoted strings, also known as **multiline strings** because the triple quotes allow the string to span more than one line.
#
# A docstring should:
#
# * Explain concisely what the function does, without getting into the details of how it works,
#
# * Explain what effect each parameter has on the behavior of the function, and
#
# * Indicate what type each parameter should be, if it is not obvious.
#
# Writing this kind of documentation is an important part of interface design.
# A well-designed interface should be simple to explain; if you have a hard time explaining one of your functions, maybe the interface could be improved.

# %% [markdown]
# ## Debugging
#
# An interface is like a contract between a function and a caller. The
# caller agrees to provide certain arguments and the function agrees to
# do certain work.
#
# For example, `polyline` requires three arguments: `n` has to be an integer; `length` should be a positive number; and `angle` has to be a number, which is understood to be in degrees.
#
# These requirements are called **preconditions** because they are supposed to be true before the function starts executing. Conversely, conditions at the end of the function are **postconditions**.
# Postconditions include the intended effect of the function (like drawing line segments) and any side effects (like moving the turtle or making other changes).
#
# Preconditions are the responsibility of the caller. If the caller violates a precondition and the function doesn't work correctly, the bug is in the caller, not the function.
#
# If the preconditions are satisfied and the postconditions are not, the bug is in the function. If your pre- and postconditions are clear, they can help with debugging.

# %% [markdown]
# ## Glossary
#
# **interface design:**
# A process for designing the interface of a function, which includes the parameters it should take.
#
# **canvas:**
# A window used to display graphical elements including lines, circles, rectangles, and other shapes.
#
# **encapsulation:**
#  The process of transforming a sequence of statements into a function definition.
#
# **generalization:**
#  The process of replacing something unnecessarily specific (like a number) with something appropriately general (like a variable or parameter).
#
# **keyword argument:**
# An argument that includes the name of the parameter.
#
# **refactoring:**
#  The process of modifying a working program to improve function interfaces and other qualities of the code.
#
# **development plan:**
# A process for writing programs.
#
# **docstring:**
#  A string that appears at the top of a function definition to document the function's interface.
#
# **multiline string:**
# A string enclosed in triple quotes that can span more than one line of a program.
#
# **precondition:**
#  A requirement that should be satisfied by the caller before a function starts.
#
# **postcondition:**
#  A requirement that should be satisfied by the function before it ends.

# %% [markdown]
# ## Exercises

# %%
# This cell tells Jupyter to provide detailed debugging information
# when a runtime error occurs. Run it before working on the exercises.

# %xmode Verbose
# Out:
# Exception reporting mode: Verbose

# %% [markdown]
# For the exercises below, there are a few more turtle functions you might want to use.
#
# * `penup` lifts the turtle's imaginary pen so it doesn't leave a trail when it moves.
#
# * `pendown` puts the pen back down.
#
# The following function uses `penup` and `pendown` to move the turtle without leaving a trail.

# %%
from jupyturtle import penup, pendown

def jump(length):
    """Move forward length units without leaving a trail.

    Postcondition: Leaves the pen down.
    """
    penup()
    forward(length)
    pendown()

# %% [markdown]
# ### Exercise
#
# Write a function called `rectangle` that draws a rectangle with given side lengths.
# For example, here's a rectangle that's `80` units wide and `40` units tall.

# %%
def rectangle(width, length):
  make_turtle()
  for i in range(2):
    forward(length)
    left(90)
    forward(width)
    left(90)

# %% [markdown]
# You can use the following code to test your function.

# %%
rectangle(40, 80)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="230.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="230.0" y1="75.0" x2="230.0" y2="35.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="230.0" y1="35.0" x2="150.0" y2="35.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="35.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### Exercise
#
# Write a function called `rhombus` that draws a rhombus with a given side length and a given interior angle. For example, here's a rhombus with side length `50` and an interior angle of `60` degrees.

# %%
def rombus(length, n):
  make_turtle()
  for i in range(2):
    forward(length)
    left(n)
    forward(length)
    n2 = 180 - n
    left(n2)

# %% [markdown]
# You can use the following code to test your function.

# %%
rombus(50, 60)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="200.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="75.0" x2="225.0" y2="31.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="225.0" y1="31.7" x2="175.0" y2="31.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="175.0" y1="31.7" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### Exercise
#
# Now write a more general function called `parallelogram` that draws a quadrilateral with parallel sides. Then rewrite `rectangle` and `rhombus` to use `parallelogram`.

# %%
def parallelogram(length1, length2, n):
  make_turtle()
  for i in range(2):
    forward(length1)
    left(n)
    forward(length2)
    left(180 - n)

# %%
parallelogram(15, 25, 60)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="165.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="165.0" y1="75.0" x2="177.5" y2="53.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="177.5" y1="53.3" x2="162.5" y2="53.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.5" y1="53.3" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %%
parallelogram(60, 30, 90)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="210.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="210.0" y1="75.0" x2="210.0" y2="45.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="210.0" y1="45.0" x2="150.0" y2="45.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="45.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %%
parallelogram(30, 60, 60)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="180.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.0" y1="75.0" x2="210.0" y2="23.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="210.0" y1="23.0" x2="180.0" y2="23.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.0" y1="23.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### Exercise
#
# Write an appropriately general set of functions that can draw shapes like this.
#
# ![](https://github.com/AllenDowney/ThinkPython/raw/v3/jupyturtle_pie.png)
#
# Hint: Write a function called `triangle` that draws one triangular segment, and then a function called `draw_pie` that uses `triangle`.

# %%
def triangle(length, n):
  calc_1 = length * math.sin(n * math.pi/180)
  right(n)
  forward(length)
  left(90 + n)
  forward(2*calc_1)
  left(90 + n)
  forward(length)
  right(180 + n)

def drawpie(number, radius):
  make_turtle()
  angle = 360 / number
  for k in range(number):
    triangle(radius, angle/2)
    left(angle)

drawpie(9, 60)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="206.4" y2="95.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="206.4" y1="95.5" x2="206.4" y2="54.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="206.4" y1="54.5" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="206.4" y2="54.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="206.4" y1="54.5" x2="180.0" y2="23.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.0" y1="23.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="180.0" y2="23.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.0" y1="23.0" x2="139.6" y2="15.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="139.6" y1="15.9" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="139.6" y2="15.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="139.6" y1="15.9" x2="104.0" y2="36.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="104.0" y1="36.4" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="104.0" y2="36.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="104.0" y1="36.4" x2="90.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="90.0" y1="75.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="90.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="90.0" y1="75.0" x2="104.0" y2="113.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="104.0" y1="113.6" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="104.0" y2="113.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="104.0" y1="113.6" x2="139.6" y2="134.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="139.6" y1="134.1" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="139.6" y2="134.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="139.6" y1="134.1" x2="180.0" y2="127.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.0" y1="127.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="180.0" y2="127.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.0" y1="127.0" x2="206.4" y2="95.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="206.4" y1="95.5" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### Exercise
#
# Write an appropriately general set of functions that can draw flowers like this.
#
# ![](https://github.com/AllenDowney/ThinkPython/raw/v3/jupyturtle_flower.png)
#
# Hint: Use `arc` to write a function called `petal` that draws one flower petal.

# %%
def petal(length, n):
  for i in range(2):
    arc(length, n)
    left(180 - n)

def flor(number, length, n):
  make_turtle(delay=0.0003)
  for i in range(number):
    petal(length, n)
    left(360 / number)

flor(8, 40, 60)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="151.4" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="151.4" y1="75.0" x2="152.8" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="152.8" y1="75.0" x2="154.2" y2="74.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="154.2" y1="74.9" x2="155.6" y2="74.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="155.6" y1="74.7" x2="157.0" y2="74.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="157.0" y1="74.5" x2="158.3" y2="74.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="158.3" y1="74.3" x2="159.7" y2="74.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="159.7" y1="74.0" x2="161.1" y2="73.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="161.1" y1="73.6" x2="162.4" y2="73.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.4" y1="73.3" x2="163.7" y2="72.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="163.7" y1="72.8" x2="165.0" y2="72.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="165.0" y1="72.3" x2="166.3" y2="71.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="166.3" y1="71.8" x2="167.6" y2="71.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="167.6" y1="71.3" x2="168.9" y2="70.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="168.9" y1="70.6" x2="170.1" y2="70.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="170.1" y1="70.0" x2="171.3" y2="69.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="171.3" y1="69.3" x2="172.5" y2="68.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="172.5" y1="68.6" x2="173.6" y2="67.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="173.6" y1="67.8" x2="174.8" y2="67.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="174.8" y1="67.0" x2="175.9" y2="66.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="175.9" y1="66.1" x2="176.9" y2="65.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="176.9" y1="65.2" x2="178.0" y2="64.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="178.0" y1="64.3" x2="179.0" y2="63.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="179.0" y1="63.3" x2="180.0" y2="62.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.0" y1="62.3" x2="180.9" y2="61.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.9" y1="61.2" x2="181.8" y2="60.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="181.8" y1="60.2" x2="182.6" y2="59.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="182.6" y1="59.1" x2="183.5" y2="57.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="183.5" y1="57.9" x2="184.2" y2="56.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="184.2" y1="56.8" x2="185.0" y2="55.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="185.0" y1="55.6" x2="183.6" y2="55.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="183.6" y1="55.6" x2="182.2" y2="55.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="182.2" y1="55.7" x2="180.8" y2="55.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.8" y1="55.8" x2="179.4" y2="55.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="179.4" y1="55.9" x2="178.0" y2="56.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="178.0" y1="56.1" x2="176.7" y2="56.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="176.7" y1="56.3" x2="175.3" y2="56.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="175.3" y1="56.6" x2="173.9" y2="57.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="173.9" y1="57.0" x2="172.6" y2="57.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="172.6" y1="57.3" x2="171.3" y2="57.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="171.3" y1="57.8" x2="170.0" y2="58.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="170.0" y1="58.3" x2="168.7" y2="58.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="168.7" y1="58.8" x2="167.4" y2="59.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="167.4" y1="59.3" x2="166.1" y2="60.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="166.1" y1="60.0" x2="164.9" y2="60.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="164.9" y1="60.6" x2="163.7" y2="61.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="163.7" y1="61.3" x2="162.5" y2="62.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.5" y1="62.1" x2="161.3" y2="62.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="161.3" y1="62.8" x2="160.2" y2="63.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="160.2" y1="63.7" x2="159.1" y2="64.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="159.1" y1="64.5" x2="158.0" y2="65.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="158.0" y1="65.4" x2="157.0" y2="66.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="157.0" y1="66.3" x2="156.0" y2="67.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="156.0" y1="67.3" x2="155.0" y2="68.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="155.0" y1="68.3" x2="154.1" y2="69.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="154.1" y1="69.4" x2="153.2" y2="70.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="153.2" y1="70.4" x2="152.3" y2="71.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="152.3" y1="71.5" x2="151.5" y2="72.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="151.5" y1="72.7" x2="150.7" y2="73.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.7" y1="73.8" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="151.0" y2="74.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="151.0" y1="74.0" x2="151.9" y2="73.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="151.9" y1="73.0" x2="152.9" y2="71.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="152.9" y1="71.9" x2="153.7" y2="70.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="153.7" y1="70.9" x2="154.6" y2="69.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="154.6" y1="69.7" x2="155.4" y2="68.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="155.4" y1="68.6" x2="156.1" y2="67.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="156.1" y1="67.4" x2="156.9" y2="66.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="156.9" y1="66.2" x2="157.5" y2="65.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="157.5" y1="65.0" x2="158.2" y2="63.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="158.2" y1="63.8" x2="158.8" y2="62.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="158.8" y1="62.5" x2="159.3" y2="61.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="159.3" y1="61.2" x2="159.8" y2="59.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="159.8" y1="59.9" x2="160.3" y2="58.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="160.3" y1="58.6" x2="160.7" y2="57.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="160.7" y1="57.3" x2="161.0" y2="55.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="161.0" y1="55.9" x2="161.3" y2="54.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="161.3" y1="54.5" x2="161.6" y2="53.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="161.6" y1="53.2" x2="161.8" y2="51.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="161.8" y1="51.8" x2="162.0" y2="50.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.0" y1="50.4" x2="162.1" y2="49.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.1" y1="49.0" x2="162.2" y2="47.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.2" y1="47.6" x2="162.2" y2="46.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.2" y1="46.2" x2="162.2" y2="44.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.2" y1="44.8" x2="162.1" y2="43.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.1" y1="43.4" x2="162.0" y2="42.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.0" y1="42.0" x2="161.8" y2="40.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="161.8" y1="40.7" x2="161.6" y2="39.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="161.6" y1="39.3" x2="161.3" y2="37.9"
#     stroke="#663399" stroke-width="2"

# %% [markdown]
# You can use the following code to test your functions.
#
# Because the solution draws a lot of small line segments, it tends to slow down as it runs.
# To avoid that, you can add the keyword argument `auto_render=False` to avoid drawing after every step, and then call the `render` function at the end to show the result.
#
# While you are debugging, you might want to remove `auto_render=False`.

# %%
from jupyturtle import render

turtle = make_turtle(auto_render=False)

jump(-60)
number = 7
length = 60
n = 60
flor(number, length, n)

jump(120)
number = 9
length = 40
n = 85
flor(number, length, n)

render()
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <g transform="rotate(-90.0,150,75) translate(150, 75)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="152.1" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="152.1" y1="75.0" x2="154.2" y2="74.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="154.2" y1="74.9" x2="156.3" y2="74.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="156.3" y1="74.8" x2="158.4" y2="74.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="158.4" y1="74.6" x2="160.4" y2="74.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="160.4" y1="74.3" x2="162.5" y2="73.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.5" y1="73.9" x2="164.5" y2="73.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="164.5" y1="73.5" x2="166.6" y2="73.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="166.6" y1="73.0" x2="168.6" y2="72.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="168.6" y1="72.4" x2="170.6" y2="71.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="170.6" y1="71.7" x2="172.6" y2="71.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="172.6" y1="71.0" x2="174.5" y2="70.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="174.5" y1="70.2" x2="176.4" y2="69.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="176.4" y1="69.4" x2="178.3" y2="68.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="178.3" y1="68.5" x2="180.1" y2="67.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.1" y1="67.5" x2="182.0" y2="66.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="182.0" y1="66.4" x2="183.7" y2="65.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="183.7" y1="65.3" x2="185.5" y2="64.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="185.5" y1="64.2" x2="187.2" y2="62.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="187.2" y1="62.9" x2="188.8" y2="61.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="188.8" y1="61.6" x2="190.4" y2="60.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="190.4" y1="60.3" x2="192.0" y2="58.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="192.0" y1="58.9" x2="193.5" y2="57.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="193.5" y1="57.4" x2="194.9" y2="55.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="194.9" y1="55.9" x2="196.3" y2="54.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="196.3" y1="54.4" x2="197.7" y2="52.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="197.7" y1="52.8" x2="199.0" y2="51.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="199.0" y1="51.1" x2="200.2" y2="49.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.2" y1="49.4" x2="201.4" y2="47.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="201.4" y1="47.7" x2="202.5" y2="45.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="202.5" y1="45.9" x2="200.4" y2="45.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.4" y1="45.9" x2="198.3" y2="46.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="198.3" y1="46.0" x2="196.2" y2="46.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="196.2" y1="46.1" x2="194.1" y2="46.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="194.1" y1="46.3" x2="192.0" y2="46.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="192.0" y1="46.6" x2="190.0" y2="47.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="190.0" y1="47.0" x2="187.9" y2="47.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="187.9" y1="47.4" x2="185.9" y2="47.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="185.9" y1="47.9" x2="183.9" y2="48.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="183.9" y1="48.5" x2="181.9" y2="49.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="181.9" y1="49.2" x2="179.9" y2="49.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="179.9" y1="49.9" x2="178.0" y2="50.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="178.0" y1="50.7" x2="176.1" y2="51.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="176.1" y1="51.5" x2="174.2" y2="52.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="174.2" y1="52.4" x2="172.3" y2="53.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="172.3" y1="53.4" x2="170.5" y2="54.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="170.5" y1="54.5" x2="168.8" y2="55.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="168.8" y1="55.6" x2="167.0" y2="56.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="167.0" y1="56.8" x2="165.3" y2="58.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="165.3" y1="58.0" x2="163.7" y2="59.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="163.7" y1="59.3" x2="162.1" y2="60.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.1" y1="60.6" x2="160.5" y2="62.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="160.5" y1="62.0" x2="159.0" y2="63.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="159.0" y1="63.5" x2="157.5" y2="65.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="157.5" y1="65.0" x2="156.1" y2="66.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="156.1" y1="66.5" x2="154.8" y2="68.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="154.8" y1="68.1" x2="153.5" y2="69.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="153.5" y1="69.8" x2="152.3" y2="71.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="152.3" y1="71.5" x2="151.1" y2="73.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="151.1" y1="73.2" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="151.3" y2="73.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="151.3" y1="73.4" x2="152.6" y2="71.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="152.6" y1="71.7" x2="153.7" y2="70.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="153.7" y1="70.0" x2="154.9" y2="68.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="154.9" y1="68.2" x2="155.9" y2="66.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="155.9" y1="66.4" x2="156.9" y2="64.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="156.9" y1="64.5" x2="157.9" y2="62.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="157.9" y1="62.7" x2="158.7" y2="60.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="158.7" y1="60.8" x2="159.5" y2="58.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="159.5" y1="58.8" x2="160.3" y2="56.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="160.3" y1="56.9" x2="161.0" y2="54.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="161.0" y1="54.9" x2="161.5" y2="52.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="161.5" y1="52.9" x2="162.1" y2="50.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.1" y1="50.9" x2="162.5" y2="48.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.5" y1="48.8" x2="162.9" y2="46.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.9" y1="46.8" x2="163.2" y2="44.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="163.2" y1="44.7" x2="163.5" y2="42.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="163.5" y1="42.6" x2="163.6" y2="40.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="163.6" y1="40.5" x2="163.7" y2="38.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="163.7" y1="38.4" x2="163.7" y2="36.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="163.7" y1="36.3" x2="163.7" y2="34.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="163.7" y1="34.2" x2="163.6" y2="32.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="163.6" y1="32.1" x2="163.4" y2="30.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="163.4" y1="30.1" x2="163.1" y2="28.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="163.1" y1="28.0" x2="162.8" y2="25.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.8" y1="25.9" x2="162.3" y2="23.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.3" y1="23.9" x2="161.9" y2="21.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="161.9" y1="21.8" x2="161.3" y2="19.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="161.3" y1="19.8" x2="160.7" y2="17.8"
#     stroke="#663399" stroke-width="2"
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="152.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="152.0" y1="75.0" x2="154.0" y2="74.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="154.0" y1="74.9" x2="155.9" y2="74.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="155.9" y1="74.7" x2="157.9" y2="74.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="157.9" y1="74.4" x2="159.8" y2="74.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="159.8" y1="74.0" x2="161.7" y2="73.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="161.7" y1="73.5" x2="163.6" y2="73.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="163.6" y1="73.0" x2="165.5" y2="72.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="165.5" y1="72.3" x2="167.3" y2="71.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="167.3" y1="71.5" x2="169.1" y2="70.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="169.1" y1="70.7" x2="170.8" y2="69.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="170.8" y1="69.7" x2="172.5" y2="68.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="172.5" y1="68.7" x2="174.2" y2="67.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="174.2" y1="67.6" x2="175.8" y2="66.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="175.8" y1="66.4" x2="177.3" y2="65.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="177.3" y1="65.2" x2="178.7" y2="63.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="178.7" y1="63.8" x2="180.1" y2="62.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.1" y1="62.4" x2="181.4" y2="60.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="181.4" y1="60.9" x2="182.7" y2="59.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="182.7" y1="59.4" x2="183.9" y2="57.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="183.9" y1="57.8" x2="184.9" y2="56.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="184.9" y1="56.2" x2="185.9" y2="54.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="185.9" y1="54.5" x2="186.9" y2="52.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="186.9" y1="52.7" x2="187.7" y2="50.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="187.7" y1="50.9" x2="188.4" y2="49.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="188.4" y1="49.1" x2="189.1" y2="47.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="189.1" y1="47.2" x2="189.6" y2="45.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="189.6" y1="45.3" x2="190.1" y2="43.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="190.1" y1="43.4" x2="190.5" y2="41.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="190.5" y1="41.4" x2="190.7" y2="39.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="190.7" y1="39.5" x2="188.8" y2="39.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="188.8" y1="39.5" x2="186.8" y2="39.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="186.8" y1="39.6" x2="184.8" y2="39.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="184.8" y1="39.8" x2="182.9" y2="40.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="182.9" y1="40.1" x2="180.9" y2="40.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.9" y1="40.5" x2="179.0" y2="40.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="179.0" y1="40.9" x2="177.1" y2="41.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="177.1" y1="41.5" x2="175.3" y2="42.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="175.3" y1="42.2" x2="173.4" y2="42.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="173.4" y1="42.9" x2="171.6" y2="43.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="171.6" y1="43.8" x2="169.9" y2="44.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="169.9" y1="44.7" x2="168.2" y2="45.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="168.2" y1="45.8" x2="166.6" y2="46.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="166.6" y1="46.9" x2="165.0" y2="48.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="165.0" y1="48.1" x2="163.5" y2="49.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="163.5" y1="49.3" x2="162.0" y2="50.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.0" y1="50.7" x2="160.6" y2="52.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="160.6" y1="52.1" x2="159.3" y2="53.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="159.3" y1="53.5" x2="158.1" y2="55.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="158.1" y1="55.1" x2="156.9" y2="56.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="156.9" y1="56.7" x2="155.8" y2="58.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="155.8" y1="58.3" x2="154.8" y2="60.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="154.8" y1="60.0" x2="153.9" y2="61.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="153.9" y1="61.8" x2="153.0" y2="63.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="153.0" y1="63.6" x2="152.3" y2="65.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="152.3" y1="65.4" x2="151.7" y2="67.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="151.7" y1="67.3" x2="151.1" y2="69.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="151.1" y1="69.2" x2="150.6" y2="71.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.6" y1="71.1" x2="150.3" y2="73.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.3" y1="73.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="151.5" y2="73.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="151.5" y1="73.7" x2="153.0" y2="72.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="153.0" y1="72.4" x2="154.3" y2="71.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="154.3" y1="71.0" x2="155.7" y2="69.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="155.7" y1="69.5" x2="156.9" y2="67.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="156.9" y1="67.9" x2="158.1" y2="66.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="158.1" y1="66.3" x2="159.1" y2="64.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="159.1" y1="64.7" x2="160.1" y2="63.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="160.1" y1="63.0" x2="161.0" y2="61.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="161.0" y1="61.2" x2="161.9" y2="59.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="161.9" y1="59.4" x2="162.6" y2="57.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.6" y1="57.6" x2="163.2" y2="55.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="163.2" y1="55.7" x2="163.8" y2="53.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="163.8" y1="53.8" x2="164.2" y2="51.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="164.2" y1="51.9" x2="164.6" y2="49.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="164.6" y1="49.9" x2="164.8" y2="48.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="164.8" y1="48.0" x2="165.0" y2="46.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="165.0" y1="46.0" x2="165.1" y2="44.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="165.1" y1="44.0" x2="165.0" y2="42.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="165.0" y1="42.0" x2="164.9" y2="40.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="164.9" y1="40.1" x2="164.7" y2="38.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="164.7" y1="38.1" x2="164.3" y2="36.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="164.3" y1="36.2" x2="163.9" y2="34.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="163.9" y1="34.2" x2="163.4" y2="32.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="163.4" y1="32.3" x2="162.8" y2="30.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.8" y1="30.4" x2="162.1" y2="28.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.1" y1="28.6" x2="161.3" y2="26.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="161.3" y1="26.8" x2="160.4" y2="25.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="160.4" y1="25.0" x2="159.4" y2="23.3"
#     stroke="#663399" stroke-width="2"

# %% [markdown]
# ### Ask a virtual assistant
#
# There are several modules like `jupyturtle` in Python, and the one we used in this chapter has been customized for this book.
# So if you ask a virtual assistant for help, it won't know which module to use.
# But if you give it a few examples to work with, it can probably figure it out.
# For example, try this prompt and see if it can write a function that draws a spiral:
#
# ```
# The following program uses a turtle graphics module to draw a circle:
#
# from jupyturtle import make_turtle, forward, left
# import math
#
# def polygon(n, length):
#     angle = 360 / n
#     for i in range(n):
#         forward(length)
#         left(angle)
#
# def circle(radius):
#     circumference = 2 * math.pi * radius
#     n = 30
#     length = circumference / n
#     polygon(n, length)
#
# make_turtle(delay=0)
# circle(30)
#
# Write a function that draws a spiral.
# ```

# %% [markdown]
# Keep in mind that the result might use features we have not seen yet, and it might have errors.
# Copy the code from the VA and see if you can get it working.
# If you didn't get what you wanted, try modifying the prompt.

# %%
#Respuesta de la IA
from jupyturtle import make_turtle, forward, left
import math

def polygon(n, length):
    angle = 360 / n
    for i in range(n):
        forward(length)
        left(angle)

def circle(radius):
    circumference = 2 * math.pi * radius
    n = 30
    length = circumference / n
    polygon(n, length)

def spiral(steps=50, initial_length=5, length_increment=2, angle=30):
    """
    Draws a spiral using turtle graphics.

    Parameters:
      steps (int): Number of line segments in the spiral.
      initial_length (float): Length of the first segment.
      length_increment (float): Amount to increase length per step.
      angle (float): Angle to turn left after each segment.
    """
    length = initial_length
    for _ in range(steps):
        forward(length)
        left(angle)
        length += length_increment

make_turtle(delay=0)
# You can draw a circle:
# circle(30)

# Draw a spiral:
spiral()

#FINAL CONCLUSION--> The code is very good. The coe itself has some issue with the size of the spiral, but does it very well. The main problem that I see is the indentation. I know that it doesn't matter, but the code comes from an IA, making it very supicious that (literally) an Artifical Intelligence has some issues with something as simple as this.
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="155.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="155.0" y1="75.0" x2="161.1" y2="71.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="161.1" y1="71.5" x2="165.6" y2="63.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="165.6" y1="63.7" x2="165.6" y2="52.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="165.6" y1="52.7" x2="159.1" y2="41.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="159.1" y1="41.4" x2="146.1" y2="33.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="146.1" y1="33.9" x2="129.1" y2="33.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="129.1" y1="33.9" x2="112.6" y2="43.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="112.6" y1="43.4" x2="102.1" y2="61.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="102.1" y1="61.6" x2="102.1" y2="84.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="102.1" y1="84.6" x2="114.6" y2="106.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="114.6" y1="106.3" x2="138.0" y2="119.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="138.0" y1="119.8" x2="167.0" y2="119.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="167.0" y1="119.8" x2="193.8" y2="104.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="193.8" y1="104.3" x2="210.3" y2="75.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="210.3" y1="75.7" x2="210.3" y2="40.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="210.3" y1="40.7" x2="191.8" y2="8.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="191.8" y1="8.7" x2="158.1" y2="-10.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="158.1" y1="-10.8" x2="117.1" y2="-10.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="117.1" y1="-10.8" x2="79.8" y2="10.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="79.8" y1="10.7" x2="57.3" y2="49.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="57.3" y1="49.6" x2="57.3" y2="96.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="57.3" y1="96.6" x2="81.8" y2="139.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="81.8" y1="139.1" x2="126.0" y2="164.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="126.0" y1="164.6" x2="179.0" y2="164.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="179.0" y1="164.6" x2="226.6" y2="137.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="226.6" y1="137.1" x2="255.1" y2="87.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="255.1" y1="87.7" x2="255.1" y2="28.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="255.1" y1="28.7" x2="224.6" y2="-24.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="224.6" y1="-24.1" x2="170.1" y2="-55.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="170.1" y1="-55.6" x2="105.1" y2="-55.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="105.1" y1="-55.6" x2="47.0" y2="-22.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="47.0" y1="-22.1" x2="12.5" y2="37.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="12.5" y1="37.6" x2="12.5" y2="108.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="12.5" y1="108.6" x2="49.0" y2="171.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="49.0" y1="171.9" x2="114.0" y2="209.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="114.0" y1="209.4" x2="191.0" y2="209.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="191.0" y1="209.4" x2="259.4" y2="169.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="259.4" y1="169.9" x2="299.9" y2="99.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="299.9" y1="99.7" x2="299.9" y2="16.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="299.9" y1="16.7" x2="257.4" y2="-56.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="257.4" y1="-56.9" x2="182.1" y2="-100.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="182.1" y1="-100.4" x2="93.1" y2="-100.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="93.1" y1="-100.4" x2="14.3" y2="-54.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="14.3" y1="-54.9" x2="-32.2" y2="25.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="-32.2" y1="25.6" x2="-32.2" y2="120.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="-32.2" y1="120.6" x2="16.3" y2="204.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="16.3" y1="204.6" x2="102.0" y2="254.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="102.0" y1="254.1" x2="203.0" y2="254.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="203.0" y1="254.1" x2="292.2" y2="202.6"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(210.0,292.2,202.6) translate(292.2, 202.6)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# [Think Python: 3rd Edition](https://allendowney.github.io/ThinkPython/index.html)
#
# Copyright 2024 [Allen B. Downey](https://allendowney.com)
#
# Code license: [MIT License](https://mit-license.org/)
#
# Text license: [Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International](https://creativecommons.org/licenses/by-nc-sa/4.0/)
