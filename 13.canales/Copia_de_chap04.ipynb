# %% [markdown]
# You can order print and ebook versions of *Think Python 3e* from
# [Bookshop.org](https://bookshop.org/a/98697/9781098155438) and
# [Amazon](https://www.amazon.com/_/dp/1098155432?smid=ATVPDKIKX0DER&_encoding=UTF8&tag=oreilly20-20&_encoding=UTF8&tag=greenteapre01-20&linkCode=ur2&linkId=e2a529f94920295d27ec8a06e757dc7c&camp=1789&creative=9325).

# %%
from os.path import basename, exists

def download(url):
    filename = basename(url)
    if not exists(filename):
        from urllib.request import urlretrieve

        local, _ = urlretrieve(url, filename)
        print("Downloaded " + str(local))
    return filename

download('https://github.com/AllenDowney/ThinkPython/raw/v3/thinkpython.py');
download('https://github.com/AllenDowney/ThinkPython/raw/v3/diagram.py');
download('https://github.com/ramalho/jupyturtle/releases/download/2024-03/jupyturtle.py');
# Out:
# Downloaded thinkpython.py
# Downloaded diagram.py
# Downloaded jupyturtle.py

# %%
import thinkpython

# %load_ext autoreload
# %autoreload 2

# %%
#hexagono
make_turtle()
def hexagono():
  for i in range(6):
    forward(40)
    left(60)

hexagono()
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="190.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="190.0" y1="75.0" x2="210.0" y2="40.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="210.0" y1="40.4" x2="190.0" y2="5.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="190.0" y1="5.7" x2="150.0" y2="5.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="5.7" x2="130.0" y2="40.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="130.0" y1="40.4" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %%
#triangulo equilatero
make_turtle()
def triangulo_equilatero():
  for i in range(3):
    forward(50)
    left(120)
triangulo_equilatero()
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="200.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="75.0" x2="175.0" y2="31.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="175.0" y1="31.7" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# # Functions and Interfaces
#
# This chapter introduces a module called `jupyturtle`, which allows you to create simple drawings by giving instructions to an imaginary turtle.
# We will use this module to write functions that draw squares, polygons, and circles -- and to demonstrate **interface design**, which is a way of designing functions that work together.

# %% [markdown]
# ## The jupyturtle module
#
# To use the `jupyturtle` module, we can import it like this.

# %%
import jupyturtle

# %% [markdown]
# Now we can use the functions defined in the module, like `make_turtle` and `forward`.

# %%
jupyturtle.make_turtle()
jupyturtle.forward(75)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="225.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,225.0,75.0) translate(225.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# `make_turtle` creates a **canvas**, which is a space on the screen where we can draw, and a turtle, which is represented by a circular shell and a triangular head.
# The circle shows the location of the turtle and the triangle indicates the direction it is facing.
#
# `forward` moves the turtle a given distance in the direction it's facing, drawing a line segment along the way.
# The distance is in arbitrary units -- the actual size depends on your computer's screen.
#
# We will use functions defined in the `jupyturtle` module many times, so it would be nice if we did not have to write the name of the module every time.
# That's possible if we import the module like this.

# %%
from jupyturtle import make_turtle, forward

# %% [markdown]
# This version of the import statement imports `make_turtle` and `forward` from the `jupyturtle` module so we can call them like this.

# %%
make_turtle()
forward(75)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="225.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,225.0,75.0) translate(225.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# `jupyturtle` provides two other functions we'll use, called `left` and `right`.
# We'll import them like this.

# %%
from jupyturtle import left, right

# %% [markdown]
# `left` causes the turtle to turn left. It takes one argument, which is the angle of the turn in degrees.
# For example, we can make a 90 degree left turn like this.

# %%
make_turtle()
forward(75)
left(90)
forward(50)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="225.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="225.0" y1="75.0" x2="225.0" y2="25.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(180.0,225.0,25.0) translate(225.0, 25.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# This program moves the turtle east and then north, leaving two line segments behind.
# Before you go on, see if you can modify the previous program to make a square.

# %% [markdown]
# ## Making a square
#
# Here's one way to make a square.

# %%
make_turtle()
forward(50)
left(90)
forward(50)
left(90)
forward(50)
left(90)
forward(50)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="200.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="75.0" x2="200.0" y2="25.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="25.0" x2="150.0" y2="25.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="25.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(0.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# Because this program repeats the same pair of lines four times, we can do the same thing more concisely with a `for` loop.

# %%
make_turtle()
#paso 1
forward(50)
left(90)
#paso 2
forward(50)
left(90)
#paso 3
forward(50)
left(90)
#paso 4
forward(50)
left(90)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="200.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="75.0" x2="200.0" y2="25.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="25.0" x2="150.0" y2="25.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="25.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ## Encapsulation and generalization
#
# Let's take the square-drawing code from the previous section and put it in a function called `square`.

# %%
def cuadrado():
    for i in range(4):
        forward(50)
        left(90)

# %% [markdown]
# Now we can call the function like this.

# %%
make_turtle()
cuadrado()
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="200.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="75.0" x2="200.0" y2="25.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="25.0" x2="150.0" y2="25.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="25.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# Wrapping a piece of code up in a function is called **encapsulation**.
# One of the benefits of encapsulation is that it attaches a name to the code, which serves as a kind of documentation. Another advantage is that if you re-use the code, it is more concise to call a function twice than to copy and paste the body!
#
# In the current version, the size of the square is always `50`.
# If we want to draw squares with different sizes, we can take the length of the sides as a parameter.

# %%
def cuadrado(length):
    for i in range(4):
        forward(length)
        left(90)

# %% [markdown]
# Now we can draw squares with different sizes.

# %%
make_turtle()
cuadrado(10)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="160.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="160.0" y1="75.0" x2="160.0" y2="65.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="160.0" y1="65.0" x2="150.0" y2="65.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="65.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
#  Adding a parameter to a function is called **generalization** because it makes the function more general: with the previous version, the square is always the same size; with this version it can be any size.
#
# If we add another parameter, we can make it even more general.
# The following function draws regular polygons with a given number of sides.

# %%
def poligono(n, tamano):
    angulo = 360 / n #angulos externos
    for i in range(n):
        forward(tamano) #moverse en base al tamaño deseado
        left(angulo) #girar en base a los angulos dados

# %% [markdown]
# In a regular polygon with `n` sides, the angle between adjacent sides is `360 / n` degrees.
#
# The following example draws a `7`-sided polygon with side length `30`.

# %%
make_turtle()
poligono(7,30)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="180.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.0" y1="75.0" x2="198.7" y2="51.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="198.7" y1="51.5" x2="192.0" y2="22.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="192.0" y1="22.3" x2="165.0" y2="9.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="165.0" y1="9.3" x2="138.0" y2="22.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="138.0" y1="22.3" x2="131.3" y2="51.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="131.3" y1="51.5" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(270.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# When a function has more than a few numeric arguments, it is easy to forget what they are, or what order they should be in.
# It can be a good idea to include the names of the parameters in the argument list.

# %%
make_turtle()
poligono(n=7, tamano=30)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="180.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.0" y1="75.0" x2="198.7" y2="51.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="198.7" y1="51.5" x2="192.0" y2="22.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="192.0" y1="22.3" x2="165.0" y2="9.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="165.0" y1="9.3" x2="138.0" y2="22.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="138.0" y1="22.3" x2="131.3" y2="51.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="131.3" y1="51.5" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(270.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# These are sometimes called "named arguments" because they include the parameter names.
# But in Python they are more often called **keyword arguments** (not to be confused with Python keywords like `for` and `def`).
#
# This use of the assignment operator, `=`, is a reminder about how arguments and parameters work -- when you call a function, the arguments are assigned to the parameters.

# %% [markdown]
# ## Approximating a circle
#
# Now suppose we want to draw a circle.
# We can do that, approximately, by drawing a polygon with a large number of sides, so each side is small enough that it's hard to see.
# Here is a function that uses `polygon` to draw a `30`-sided polygon that approximates a circle.

# %%
import math

def circulo(radio):
    circunferencia = 2 * math.pi * radio
    n=100
    tamano = circunferencia / n
    poligono(n, tamano)

# %% [markdown]
# `circle` takes the radius of the the circle as a parameter.
# It computes `circumference`, which is the circumference of a circle with the given radius.
# `n` is the number of sides, so `circumference / n` is the length of each side.
#
# This function might take a long time to run.
# We can speed it up by calling `make_turtle` with a keyword argument called `delay` that sets the time, in seconds, the turtle waits after each step.
# The default value is `0.2` seconds -- if we set it to `0.02` it runs about 10 times faster.

# %%
make_turtle(delay=0.01)
circulo(30)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="151.9" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="151.9" y1="75.0" x2="153.8" y2="74.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="153.8" y1="74.9" x2="155.6" y2="74.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="155.6" y1="74.6" x2="157.5" y2="74.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="157.5" y1="74.3" x2="159.3" y2="73.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="159.3" y1="73.8" x2="161.1" y2="73.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="161.1" y1="73.2" x2="162.9" y2="72.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.9" y1="72.5" x2="164.6" y2="71.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="164.6" y1="71.7" x2="166.2" y2="70.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="166.2" y1="70.8" x2="167.8" y2="69.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="167.8" y1="69.8" x2="169.3" y2="68.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="169.3" y1="68.7" x2="170.8" y2="67.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="170.8" y1="67.5" x2="172.2" y2="66.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="172.2" y1="66.2" x2="173.4" y2="64.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="173.4" y1="64.9" x2="174.7" y2="63.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="174.7" y1="63.4" x2="175.8" y2="61.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="175.8" y1="61.9" x2="176.8" y2="60.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="176.8" y1="60.3" x2="177.7" y2="58.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="177.7" y1="58.6" x2="178.5" y2="56.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="178.5" y1="56.9" x2="179.2" y2="55.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="179.2" y1="55.2" x2="179.8" y2="53.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="179.8" y1="53.4" x2="180.2" y2="51.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.2" y1="51.6" x2="180.6" y2="49.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.6" y1="49.7" x2="180.8" y2="47.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.8" y1="47.8" x2="180.9" y2="46.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.9" y1="46.0" x2="180.9" y2="44.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="180
y2="66.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="129.7" y1="66.2" x2="131.1" y2="67.5"
#     stroke="#663399" stroke-width="2"

# %% [markdown]
# A limitation of this solution is that `n` is a constant, which means
# that for very big circles, the sides are too long, and for small
# circles, we waste time drawing very short sides.
# One option is to generalize the function by taking `n` as a parameter.
# But let's keep it simple for now.

# %% [markdown]
# ## Refactoring
#
# Now let's write a more general version of `circle`, called `arc`, that takes a second parameter, `angle`, and draws an arc of a circle that spans the given angle.
# For example, if `angle` is `360` degrees, it draws a complete circle. If `angle` is `180` degrees, it draws a half circle.
#
# To write `circle`, we were able to reuse `polygon`, because a many-sided polygon is a good approximation of a circle.
# But we can't use `polygon` to write `arc`.
#
# Instead, we'll create the more general version of `polygon`, called `polyline`.

# %%
def polilinea(n, tamano2, angulo):
    for i in range(n):
        forward(tamano2)
        left(angulo)

        #a diferencia del codigo anterior que tuvimos no era nesesario el tamaño

# %% [markdown]
# `polyline` takes as parameters the number of line segments to draw, `n`, the length of the segments, `length`, and the angle between them, `angle`.
#
# Now we can rewrite `polygon` to use `polyline`.

# %%
def poligono(n, tamano):
    angulo = 360 / n
    polilinea(n, tamano, angulo)
    angulo = 360

# %% [markdown]
# And we can use `polyline` to write `arc`.

# %%
def arco(radio, angulo):
    tamanoarco = 2 * math.pi * radio * angulo / 360
    n = 30
    tamano = tamanoarco / n
    stepangulo = angulo / n
    polilinea(n, tamano, stepangulo)

# %% [markdown]
# `arc` is similar to `circle`, except that it computes `arc_length`, which is a fraction of the circumference of a circle.
#
# Finally, we can rewrite `circle` to use `arc`.

# %%
def circulo2(radio):
    arco(radio,  360)

# %% [markdown]
# To check that these functions work as expected, we'll use them to draw something like a snail.
# With `delay=0`, the turtle runs as fast as possible.

# %%
make_turtle(delay=0.00001)
poligono(30, tamano=7)
arco(radio=100, angulo=50)
circulo2(radio=20)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="157.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="157.0" y1="75.0" x2="163.8" y2="73.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="163.8" y1="73.5" x2="170.2" y2="70.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="170.2" y1="70.7" x2="175.9" y2="66.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="175.9" y1="66.6" x2="180.6" y2="61.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.6" y1="61.4" x2="184.1" y2="55.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="184.1" y1="55.3" x2="186.3" y2="48.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="186.3" y1="48.7" x2="187.0" y2="41.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="187.0" y1="41.7" x2="186.3" y2="34.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="186.3" y1="34.7" x2="184.1" y2="28.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="184.1" y1="28.1" x2="180.6" y2="22.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.6" y1="22.0" x2="175.9" y2="16.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="175.9" y1="16.8" x2="170.2" y2="12.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="170.2" y1="12.7" x2="163.8" y2="9.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="163.8" y1="9.9" x2="157.0" y2="8.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="157.0" y1="8.4" x2="150.0" y2="8.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="8.4" x2="143.2" y2="9.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="143.2" y1="9.9" x2="136.8" y2="12.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="136.8" y1="12.7" x2="131.1" y2="16.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="131.1" y1="16.8" x2="126.4" y2="22.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="126.4" y1="22.0" x2="122.9" y2="28.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="122.9" y1="28.1" x2="120.7" y2="34.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="120.7" y1="34.7" x2="120.0" y2="41.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="120.0" y1="41.7" x2="120.7" y2="48.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="120.7" y1="48.7" x2="122.9" y2="55.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="122.9" y1="55.3" x2="126.4" y2="61.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="126.4" y1="61.4" x2="131.1" y2="66.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="131.1" y1="66.6" x2="136.8" y2="70.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="136.8" y1="70.7" x2="143.2" y2="73.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="143.2" y1="73.5" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="152.9" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="152.9" y1="75.0" x2="155.8" y2="74.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="155.8" y1="74.9" x2="158.7" y2="74.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="158.7" y1="74.7" x2="161.6" y2="74.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="161.6" y1="74.5" x2="164.5" y2="74.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="164.5" y1="74.2" x2="167.4" y2="73.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="167.4" y1="73.7" x2="170.3" y2="73.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="170.3" y1="73.2" x2="173.1" y2="72.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="173.1" y1="72.6" x2="175.9" y2="72.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="175.9" y1="72.0" x2="178.7" y2="71.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="178.7" y1="71.2" x2="181.5" y2="70.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="181.5" y1="70.4" x2="184.3" y2="69.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="184.3" y1="69.5" x2="187.0" y2="68.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="187.0" y1="68.5" x2="189.7" y2="67.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="189.7" y1="67.4" x2="192.4" y2="66.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="192.4" y1="66.2" x2="195.0" y2="65.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="195.0" y1="65.0" x2="197.6" y2="63.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="197.6" y1="63.7" x2="200.2" y2="62.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.2" y1="62.3" x2="202.7" y2="60.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="202.7" y1="60.9" x2="205.2" y2="59.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="205.2" y1="59.3" x2="207.6" y2="57.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="207.6" y1="57.8" x2="210.0" y2="56.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="210.0" y1="56.1" x2="212.3" y2="54.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="212.3" y1="54.3" x2="214.6" y2="52.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="214.6" y1="52.5" x2="216.8" y2="50.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="216.8" y1="50.7" x2="219.0" y2="48.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="219.0" y1="48.7" x2="221.1" y2="46.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="221.1" y1="46.7" x2="223.2" y2="44.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="223.2" y1="44.7" x2="225.2" y2="42.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="225.2" y1="42.6" x2="227.1" y2="40.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="227.1" y1="40.4" x2="229.8" y2="37.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="229.8" y1="37.2" x2="231.8" y2="33.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="231.8" y1="33.5" x2="232.9" y2="29.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="232.9" y1="29.5" x2="233.2" y2="25.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="233.2" y1="25.3" x2="232.6" y2="21.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="232.6" y1="21.1" x2="231.2" y2="17.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="231.2" y1="17.2" x2="229.0" y2="13.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="229.0" y1="13.6" x2="226.1" y2="10.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="226.1" y1="10.6" x2="222.6" y2="8.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="222.6" y1="8.3" x2="218.7" y2="6.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="218.7" y1="6.7" x2="214.6" y2="6.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="214.6" y1="6.0" x2="210.4" y2="6.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="210.4" y1="6.1" x2="206.3" y2="7.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="206.3" y1="7.2" x2="202.6" y2="9.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="202.6" y1="9.0" x2="199.3" y2="11.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="199.3" y1="11.6" x2="196.6" y2="14.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="196.6" y1="14.8" x2="194.6" y2="18.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="194.6" y1="18.5" x2="193.5" y2="22.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="193.5" y1="22.5" x2="193.2" y2="26.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="193.2" y1="26.7" x2="193.8" y2="30.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="193.8" y1="30.8" x2="195.2" y2="34.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="195.2" y1="34.8" x2="197.4" y2="38.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="197.4" y1="38.3" x2="200.3" y2="41.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.3" y1="41.3" x2="203.8" y2="43.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="203.8" y1="43.7" x2="207.7" y2="45.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="207.7" y1="45.2" x2="211.8" y2="46.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="211.8" y1="46.0" x2="216.0" y2="45.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="216.0" y1="45.8" x2="220.1" y2="44.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="220.1" y1="44.8" x2="223.8" y2="43.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="223.8"

# %% [markdown]
# In this example, we started with working code and reorganized it with different functions.
# Changes like this, which improve the code without changing its behavior, are called **refactoring**.
#
# If we had planned ahead, we might have written `polyline` first and avoided refactoring, but often you don't know enough at the beginning of a project to design all the functions.
# Once you start coding, you understand the problem better.
# Sometimes refactoring is a sign that you have learned something.

# %% [markdown]
# ## Stack diagram
#
# When we call `circle`, it calls `arc`, which calls `polyline`.
# We can use a stack diagram to show this sequence of function calls and the parameters for each one.

# %%
from diagram import make_binding, make_frame, Frame, Stack

frame1 = make_frame(dict(radius=30), name='circle', loc='left')

frame2 = make_frame(dict(radius=30, angle=360), name='arc', loc='left', dx=1.1)

frame3 = make_frame(dict(n=60, length=3.04, angle=5.8),
                    name='polyline', loc='left', dx=1.1, offsetx=-0.27)

stack = Stack([frame1, frame2, frame3], dy=-0.4)

# %%
from diagram import diagram, adjust

width, height, x, y = [3.58, 1.31, 0.98, 1.06]
ax = diagram(width, height)
bbox = stack.draw(ax, x, y)
#adjust(x, y, bbox)

# %% [markdown]
# Notice that the value of `angle` in `polyline` is different from the value of `angle` in `arc`.
# Parameters are local, which means you can use the same parameter name in different functions; it's a different variable in each function, and it can refer to a different value.

# %% [markdown]
# ## A development plan
#
# A **development plan** is a process for writing programs.
# The process we used in this chapter is "encapsulation and generalization".
# The steps of this process are:
#
# 1.  Start by writing a small program with no function definitions.
#
# 2.  Once you get the program working, identify a coherent piece of it,
#     encapsulate the piece in a function and give it a name.
#
# 3.  Generalize the function by adding appropriate parameters.
#
# 4.  Repeat Steps 1 to 3 until you have a set of working functions.
#
# 5.  Look for opportunities to improve the program by refactoring. For
#     example, if you have similar code in several places, consider
#     factoring it into an appropriately general function.
#
# This process has some drawbacks -- we will see alternatives later -- but it can be useful if you don't know ahead of time how to divide the program into functions.
# This approach lets you design as you go along.

# %% [markdown]
# The design of a function has two parts:
#
# * The **interface** is how the function is used, including its name, the parameters it takes and what the function is supposed to do.
#
# * The **implementation** is how the function does what it's supposed to do.
#
# For example, here's the first version of `circle` we wrote, which uses `polygon`.

# %%
def circulo3(radio):
  circunferencia = 2 * math.pi * radio
  tamano3 = circunferencia / x
  poligono(x, tamano3)
  x = 50

# %% [markdown]
# And here's the refactored version that uses `arc`.

# %%
def circulo3(radio):
  arco(radio, 360)

# %% [markdown]
# These two functions have the same interface -- they take the same parameters and do the same thing -- but they have different implementations.

# %% [markdown]
# ## Docstrings
#
# A **docstring** is a string at the beginning of a function that explains the interface ("doc" is short for "documentation").
# Here is an example:

# %%
make_turtle()
def hexagono():
  """Dibuja con turtle un hexagono con un lado determinado.
ocupa forward que es para que la tortuga avance
y left que es para que la tortuga gire a la izquierda
el 6 es el numero de lados que tiene el hexagono
"""

  for i in range(6):
    forward(40)
    left(60)

hexagono()
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="190.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="190.0" y1="75.0" x2="210.0" y2="40.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="210.0" y1="40.4" x2="190.0" y2="5.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="190.0" y1="5.7" x2="150.0" y2="5.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="5.7" x2="130.0" y2="40.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="130.0" y1="40.4" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# By convention, docstrings are triple-quoted strings, also known as **multiline strings** because the triple quotes allow the string to span more than one line.
#
# A docstring should:
#
# * Explain concisely what the function does, without getting into the details of how it works,
#
# * Explain what effect each parameter has on the behavior of the function, and
#
# * Indicate what type each parameter should be, if it is not obvious.
#
# Writing this kind of documentation is an important part of interface design.
# A well-designed interface should be simple to explain; if you have a hard time explaining one of your functions, maybe the interface could be improved.

# %% [markdown]
# ## Debugging
#
# An interface is like a contract between a function and a caller. The
# caller agrees to provide certain arguments and the function agrees to
# do certain work.
#
# For example, `polyline` requires three arguments: `n` has to be an integer; `length` should be a positive number; and `angle` has to be a number, which is understood to be in degrees.
#
# These requirements are called **preconditions** because they are supposed to be true before the function starts executing. Conversely, conditions at the end of the function are **postconditions**.
# Postconditions include the intended effect of the function (like drawing line segments) and any side effects (like moving the turtle or making other changes).
#
# Preconditions are the responsibility of the caller. If the caller violates a precondition and the function doesn't work correctly, the bug is in the caller, not the function.
#
# If the preconditions are satisfied and the postconditions are not, the bug is in the function. If your pre- and postconditions are clear, they can help with debugging.

# %% [markdown]
# ## Glossary
#
# **interface design:**
# A process for designing the interface of a function, which includes the parameters it should take.
#
# **canvas:**
# A window used to display graphical elements including lines, circles, rectangles, and other shapes.
#
# **encapsulation:**
#  The process of transforming a sequence of statements into a function definition.
#
# **generalization:**
#  The process of replacing something unnecessarily specific (like a number) with something appropriately general (like a variable or parameter).
#
# **keyword argument:**
# An argument that includes the name of the parameter.
#
# **refactoring:**
#  The process of modifying a working program to improve function interfaces and other qualities of the code.
#
# **development plan:**
# A process for writing programs.
#
# **docstring:**
#  A string that appears at the top of a function definition to document the function's interface.
#
# **multiline string:**
# A string enclosed in triple quotes that can span more than one line of a program.
#
# **precondition:**
#  A requirement that should be satisfied by the caller before a function starts.
#
# **postcondition:**
#  A requirement that should be satisfied by the function before it ends.

# %% [markdown]
# ## Exercises

# %% [markdown]
# For the exercises below, there are a few more turtle functions you might want to use.
#
# * `penup` lifts the turtle's imaginary pen so it doesn't leave a trail when it moves.
#
# * `pendown` puts the pen back down.
#
# The following function uses `penup` and `pendown` to move the turtle without leaving a trail.

# %%
from jupyturtle import penup, pendown

def sube(tamano):
    penup()
    forward(tamano)
    pendown()

# %% [markdown]
# ### Exercise
#
# Write a function called `rectangle` that draws a rectangle with given side lengths.
# For example, here's a rectangle that's `80` units wide and `40` units tall.

# %%
def rectangulo(tamano3, tamano4):
    for i in range(2):
        forward(tamano3)
        left(90)
        forward(tamano4)
        left(90)

# %% [markdown]
# You can use the following code to test your function.

# %%
make_turtle()
rectangulo(100, 20)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="250.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="250.0" y1="75.0" x2="250.0" y2="55.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="250.0" y1="55.0" x2="150.0" y2="55.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="55.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### Exercise
#
# Write a function called `rhombus` that draws a rhombus with a given side length and a given interior angle. For example, here's a rhombus with side length `50` and an interior angle of `60` degrees.

# %%
def rombo(tamano, angulo):
    for i in range(2):
        forward(tamano)
        left(angulo)
        forward(tamano)
        left(180-angulo)

# %% [markdown]
# You can use the following code to test your function.

# %%
make_turtle()
rombo(20,60)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="170.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="170.0" y1="75.0" x2="180.0" y2="57.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.0" y1="57.7" x2="160.0" y2="57.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="160.0" y1="57.7" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### Exercise
#
# Now write a more general function called `parallelogram` that draws a quadrilateral with parallel sides. Then rewrite `rectangle` and `rhombus` to use `parallelogram`.

# %%
def paralelogramo(tamano1, tamano2, angulo):
    for i in range(2):
        forward(tamano1)
        left(angulo)
        forward(tamano2)
        left(180-angulo)

# %%
def rectangulo(tamano1, tamano2):
    paralelogramo(tamano1, tamano2, 90)

# %%
def rombo(tamano, angulo):
    paralelogramo(tamano, tamano, angulo)

# %% [markdown]
# You can use the following code to test your functions.

# %%
make_turtle(width=400)
sube(-120)

rectangulo(50, 20)
sube(100)
rombo(30, 60)
sube(80)
paralelogramo(100, 25, 40)
# Out:
# <svg width="400" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="80.0" y1="75.0" x2="130.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="130.0" y1="75.0" x2="130.0" y2="55.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="130.0" y1="55.0" x2="80.0" y2="55.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="80.0" y1="55.0" x2="80.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.0" y1="75.0" x2="210.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="210.0" y1="75.0" x2="225.0" y2="49.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="225.0" y1="49.0" x2="195.0" y2="49.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="195.0" y1="49.0" x2="180.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="260.0" y1="75.0" x2="360.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="360.0" y1="75.0" x2="379.2" y2="58.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="379.2" y1="58.9" x2="279.2" y2="58.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="279.2" y1="58.9" x2="260.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,260.0,75.0) translate(260.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### Exercise
#
# Write an appropriately general set of functions that can draw shapes like this.
#
# ![](https://github.com/AllenDowney/ThinkPython/raw/v3/jupyturtle_pie.png)
#
# Hint: Write a function called `triangle` that draws one triangular segment, and then a function called `draw_pie` that uses `triangle`.

# %%
def triangulo(radio,  angulo):
    y = radio * math.sin(angulo * math.pi / 180)

    right(angulo)
    forward(radio)
    left(90+angulo)
    forward(2*y)
    left(90+angulo)
    forward(radio)
    left(180-angulo)

# %%
def cosa_rara_pie(z, radio):

    angulo = 360.0 / z
    for i in range(z):
        triangulo(radio,  angulo/2)
        left(angulo)

# %% [markdown]
# You can use the following code to test your functions.

# %%
make_turtle(delay=0.01)
sube(-80)

tamano1 = 40
cosa_rara_pie(5, tamano1)
sube(2*tamano1)
cosa_rara_pie(5, tamano1)
sube(2*tamano1)
cosa_rara_pie(7, tamano1)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="70.0" y1="75.0" x2="102.4" y2="98.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="102.4" y1="98.5" x2="102.4" y2="51.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="102.4" y1="51.5" x2="70.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="70.0" y1="75.0" x2="102.4" y2="51.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="102.4" y1="51.5" x2="57.6" y2="37.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="57.6" y1="37.0" x2="70.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="70.0" y1="75.0" x2="57.6" y2="37.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="57.6" y1="37.0" x2="30.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="30.0" y1="75.0" x2="70.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="70.0" y1="75.0" x2="30.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="30.0" y1="75.0" x2="57.6" y2="113.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="57.6" y1="113.0" x2="70.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="70.0" y1="75.0" x2="57.6" y2="113.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="57.6" y1="113.0" x2="102.4" y2="98.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="102.4" y1="98.5" x2="70.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="182.4" y2="98.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="182.4" y1="98.5" x2="182.4" y2="51.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="182.4" y1="51.5" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="182.4" y2="51.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="182.4" y1="51.5" x2="137.6" y2="37.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="137.6" y1="37.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="137.6" y2="37.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="137.6" y1="37.0" x2="110.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="110.0" y1="75.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="110.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="110.0" y1="75.0" x2="137.6" y2="113.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="137.6" y1="113.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="137.6" y2="113.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="137.6" y1="113.0" x2="182.4" y2="98.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="182.4" y1="98.5" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="230.0" y1="75.0" x2="266.0" y2="92.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="266.0" y1="92.4" x2="266.0" y2="57.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="266.0" y1="57.6" x2="230.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="230.0" y1="75.0" x2="266.0" y2="57.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="266.0" y1="57.6" x2="238.9" y2="36.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="238.9" y1="36.0" x2="230.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="230.0" y1="75.0" x2="238.9" y2="36.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="238.9" y1="36.0" x2="205.1" y2="43.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="205.1" y1="43.7" x2="230.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="230.0" y1="75.0" x2="205.1" y2="43.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="205.1" y1="43.7" x2="190.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="190.0" y1="75.0" x2="230.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="230.0" y1="75.0" x2="190.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="190.0" y1="75.0" x2="205.1" y2="106.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="205.1" y1="106.3" x2="230.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="230.0" y1="75.0" x2="205.1" y2="106.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="205.1" y1="106.3" x2="238.9" y2="114.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="238.9" y1="114.0" x2="230.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="230.0" y1="75.0" x2="238.9" y2="114.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="238.9" y1="114.0" x2="266.0" y2="92.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="266.0" y1="92.4" x2="230.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(270.0,230.0,75.0) translate(230.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %%
with open("jupyturtle_pie.svg", "w") as svg_file:
    svg_content = turtle.get_SVG()
    svg_file.write(svg_content)

# %% [markdown]
# ### Exercise
#
# Write an appropriately general set of functions that can draw flowers like this.
#
# ![](https://github.com/AllenDowney/ThinkPython/raw/v3/jupyturtle_flower.png)
#
# Hint: Use `arc` to write a function called `petal` that draws one flower petal.

# %%
def petalo(radio, angulo):

    for i in range(2):
        arco(radio,  angulo)
        left(180-angulo)

# %%
def flor_completa(z, radio, angulo):

    for i in range(z):
        petalo(radio,  angulo)
        left(360.0/z)

# %% [markdown]
# You can use the following code to test your functions.
#
# Because the solution draws a lot of small line segments, it tends to slow down as it runs.
# To avoid that, you can add the keyword argument `auto_render=False` to avoid drawing after every step, and then call the `render` function at the end to show the result.
#
# While you are debugging, you might want to remove `auto_render=False`.

# %%
from jupyturtle import render

turtle = make_turtle(auto_render=False)

sube(-60)
n = 7
radius = 40
angle = 60
flor_completa(n, radius, angle)

sube(120)
n = 9
radius = 40
angle = 85
flor_completa(n, radius, angle)

render()
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="90.0" y1="75.0" x2="91.4" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="91.4" y1="75.0" x2="92.8" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="92.8" y1="75.0" x2="94.2" y2="74.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="94.2" y1="74.9" x2="95.6" y2="74.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="95.6" y1="74.7" x2="97.0" y2="74.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="97.0" y1="74.5" x2="98.3" y2="74.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="98.3" y1="74.3" x2="99.7" y2="74.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="99.7" y1="74.0" x2="101.1" y2="73.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="101.1" y1="73.6" x2="102.4" y2="73.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="102.4" y1="73.3" x2="103.7" y2="72.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="103.7" y1="72.8" x2="105.0" y2="72.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="105.0" y1="72.3" x2="106.3" y2="71.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="106.3" y1="71.8" x2="107.6" y2="71.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="107.6" y1="71.3" x2="108.9" y2="70.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="108.9" y1="70.6" x2="110.1" y2="70.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="110.1" y1="70.0" x2="111.3" y2="69.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="111.3" y1="69.3" x2="112.5" y2="68.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="112.5" y1="68.6" x2="113.6" y2="67.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="113.6" y1="67.8" x2="114.8" y2="67.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="114.8" y1="67.0" x2="115.9" y2="66.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="115.9" y1="66.1" x2="116.9" y2="65.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="116.9" y1="65.2" x2="118.0" y2="64.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="118.0" y1="64.3" x2="119.0" y2="63.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="119.0" y1="63.3" x2="120.0" y2="62.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="120.0" y1="62.3" x2="120.9" y2="61.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="120.9" y1="61.2" x2="121.8" y2="60.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="121.8" y1="60.2" x2="122.6" y2="59.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="122.6" y1="59.1" x2="123.5" y2="57.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="123.5" y1="57.9" x2="124.2" y2="56.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="124.2" y1="56.8" x2="125.0" y2="55.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="125.0" y1="55.6" x2="123.6" y2="55.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="123.6" y1="55.6" x2="122.2" y2="55.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="122.2" y1="55.7" x2="120.8" y2="55.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="120.8" y1="55.8" x2="119.4" y2="55.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="119.4" y1="55.9" x2="118.0" y2="56.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="118.0" y1="56.1" x2="116.7" y2="56.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="116.7" y1="56.3" x2="115.3" y2="56.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="115.3" y1="56.6" x2="113.9" y2="57.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="113.9" y1="57.0" x2="112.6" y2="57.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="112.6" y1="57.3" x2="111.3" y2="57.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="111.3" y1="57.8" x2="110.0" y2="58.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="110.0" y1="58.3" x2="108.7" y2="58.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="108.7" y1="58.8" x2="107.4" y2="59.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="107.4" y1="59.3" x2="106.1" y2="60.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="106.1" y1="60.0" x2="104.9" y2="60.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="104.9" y1="60.6" x2="103.7" y2="61.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="103.7" y1="61.3" x2="102.5" y2="62.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="102.5" y1="62.1" x2="101.3" y2="62.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="101.3" y1="62.8" x2="100.2" y2="63.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="100.2" y1="63.7" x2="99.1" y2="64.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="99.1" y1="64.5" x2="98.0" y2="65.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="98.0" y1="65.4" x2="97.0" y2="66.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="97.0" y1="66.3" x2="96.0" y2="67.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="96.0" y1="67.3" x2="95.0" y2="68.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="95.0" y1="68.3" x2="94.1" y2="69.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="94.1" y1="69.4" x2="93.2" y2="70.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="93.2" y1="70.4" x2="92.3" y2="71.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="92.3" y1="71.5" x2="91.5" y2="72.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="91.5" y1="72.7" x2="90.7" y2="73.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="90.7" y1="73.8" x2="90.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="90.0" y1="75.0" x2="90.9" y2="73.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="90.9" y1="73.9" x2="91.7" y2="72.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="91.7" y1="72.8" x2="92.5" y2="71.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="92.5" y1="71.6" x2="93.2" y2="70.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="93.2" y1="70.5" x2="94.0" y2="69.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="94.0" y1="69.3" x2="94.6" y2="68.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="94.6" y1="68.0" x2="95.2" y2="66.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="95.2" y1="66.8" x2="95.8" y2="65.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="95.8" y1="65.5" x2="96.4" y2="64.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="96.4" y1="64.2" x2="96.9" y2="62.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="96.9" y1="62.9" x2="97.3" y2="61.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="97.3" y1="61.6" x2="97.7" y2="60.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="97.7" y1="60.3" x2="98.1" y2="58.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="98.1" y1="58.9" x2="98.4" y2="57.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="98.4" y1="57.5" x2="98.6" y2="56.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="98.6" y1="56.2" x2="98.8" y2="54.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="98.8" y1="54.8" x2="99.0" y2="53.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="99.0" y1="53.4" x2="99.1" y2="52.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="99.1" y1="52.0" x2="99.2" y2="50.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="99.2" y1="50.6" x2="99.2" y2="49.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="99.2" y1="49.2" x2="99.1" y2="47.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="99.1" y1="47.8" x2="99.0" y2="46.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="99.0" y1="46.4" x2="98.9" y2="45.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="98.9" y1="45.0" x2="98.7" y2="43.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="98.7" y1="43.7" x2="98.5" y2="42.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="98.5" y1="42.3" x2="98.2" y2="40.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="98.2" y1="40.9" x2="97.9" y2="39.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="97.9" y1="39.5" x2="97.5" y2="38.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="97.5" y1="38.2" x2="97.1" y2="36.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="97.1" y1="36.9" x2="96.7" y2="35.6"
#     stroke="#663399" stroke-width="2" />

# %%
with open("jupyturtle_flower.svg", "w") as svg_file:
    svg_content = turtle.get_SVG()
    svg_file.write(svg_content)

# %% [markdown]
# ### Ask a virtual assistant
#
# There are several modules like `jupyturtle` in Python, and the one we used in this chapter has been customized for this book.
# So if you ask a virtual assistant for help, it won't know which module to use.
# But if you give it a few examples to work with, it can probably figure it out.
# For example, try this prompt and see if it can write a function that draws a spiral:
#
# ```
# The following program uses a turtle graphics module to draw a circle:
#
# from jupyturtle import make_turtle, forward, left
# import math
#
# def polygon(n, length):
#     angle = 360 / n
#     for i in range(n):
#         forward(length)
#         left(angle)
#
# def circle(radius):
#     circumference = 2 * math.pi * radius
#     n = 30
#     length = circumference / n
#     polygon(n, length)
#
# make_turtle(delay=0)
# circle(30)
#
# Write a function that draws a spiral.
# ```

# %% [markdown]
# Keep in mind that the result might use features we have not seen yet, and it might have errors.
# Copy the code from the VA and see if you can get it working.
# If you didn't get what you wanted, try modifying the prompt.

# %%
from jupyturtle import make_turtle, forward, left
import math

def circular_spiral(radius_inicial, angulo):
    make_turtle(delay=0.00000000000000000000000000001, width=600, height=600)  # Crear lienzo más grande
    radio = radius_inicial
    vueltas = 5  # Número de vueltas completas

    for _ in range(vueltas * 360):  # Un paso por cada grado
        distancia = 2 * math.pi * radio / 360  # Longitud de arco por grado
        forward(distancia)
        left(angulo)
        radio += 0.1  # Aumenta el radio para formar la espiral

# Ejecutar la función
circular_spiral(30, 1)
# Out:
# <svg width="600" height="600">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1