# %% [markdown]
# <a href="https://colab.research.google.com/github/diegograndon/sieb/blob/main/capitulo_4_tomas_urrutia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# You can order print and ebook versions of *Think Python 3e* from
# [Bookshop.org](https://bookshop.org/a/98697/9781098155438) and
# [Amazon](https://www.amazon.com/_/dp/1098155432?smid=ATVPDKIKX0DER&_encoding=UTF8&tag=oreilly20-20&_encoding=UTF8&tag=greenteapre01-20&linkCode=ur2&linkId=e2a529f94920295d27ec8a06e757dc7c&camp=1789&creative=9325).

# %%
from os.path import basename, exists

def download(url):
    filename = basename(url)
    if not exists(filename):
        from urllib.request import urlretrieve

        local, _ = urlretrieve(url, filename)
        print("Downloaded " + str(local))
    return filename

download('https://github.com/AllenDowney/ThinkPython/raw/v3/thinkpython.py');
download('https://github.com/AllenDowney/ThinkPython/raw/v3/diagram.py');
download('https://github.com/ramalho/jupyturtle/releases/download/2024-03/jupyturtle.py');
# Out:
# Downloaded thinkpython.py
# Downloaded diagram.py
# Downloaded jupyturtle.py

# %%
import thinkpython

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Functions and Interfaces
#
# This chapter introduces a module called `jupyturtle`, which allows you to create simple drawings by giving instructions to an imaginary turtle.
# We will use this module to write functions that draw squares, polygons, and circles -- and to demonstrate **interface design**, which is a way of designing functions that work together.

# %% [markdown]
# ## The jupyturtle module
#
# To use the `jupyturtle` module, we can import it like this.

# %%
import jupyturtle

# %% [markdown]
# Now we can use the functions defined in the module, like `make_turtle` and `forward`.

# %%
jupyturtle.make_turtle()
jupyturtle.forward(100)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="250.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,250.0,75.0) translate(250.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# `make_turtle` creates a **canvas**, which is a space on the screen where we can draw, and a turtle, which is represented by a circular shell and a triangular head.
# The circle shows the location of the turtle and the triangle indicates the direction it is facing.
#
# `forward` moves the turtle a given distance in the direction it's facing, drawing a line segment along the way.
# The distance is in arbitrary units -- the actual size depends on your computer's screen.
#
# We will use functions defined in the `jupyturtle` module many times, so it would be nice if we did not have to write the name of the module every time.
# That's possible if we import the module like this.

# %%
from jupyturtle import make_turtle, forward

# %% [markdown]
# This version of the import statement imports `make_turtle` and `forward` from the `jupyturtle` module so we can call them like this.

# %%
make_turtle()
forward(100)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="250.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,250.0,75.0) translate(250.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# `jupyturtle` provides two other functions we'll use, called `left` and `right`.
# We'll import them like this.

# %%
from jupyturtle import left, right
make_turtle()
forward(50)
left(90)
forward(50)
right(90)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="200.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="75.0" x2="200.0" y2="25.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,200.0,25.0) translate(200.0, 25.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# `left` causes the turtle to turn left. It takes one argument, which is the angle of the turn in degrees.
# For example, we can make a 90 degree left turn like this.

# %%
from jupyturtle import left, right
jupyturtle.make_turtle()
jupyturtle.forward(50)
jupyturtle.left(90)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="200.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(180.0,200.0,75.0) translate(200.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# This program moves the turtle east and then north, leaving two line segments behind.
# Before you go on, see if you can modify the previous program to make a square.

# %% [markdown]
# ## Making a square
#
# Here's one way to make a square.

# %%
import jupyturtle
make_turtle()
forward(50)
left(90)
forward(50)
left(90)
forward(50)
left(90)
forward(50)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="200.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="75.0" x2="200.0" y2="25.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="25.0" x2="150.0" y2="25.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="25.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(0.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# Because this program repeats the same pair of lines four times, we can do the same thing more concisely with a `for` loop.

# %%
from jupyturtle import left, right
make_turtle()
for i in range(4):
    forward(50)
    left(90)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="200.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="75.0" x2="200.0" y2="25.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="25.0" x2="150.0" y2="25.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="25.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ## Encapsulation and generalization
#
# Let's take the square-drawing code from the previous section and put it in a function called `square`.

# %%
def square():
  for i in range(4):
    forward(50)
    left(90)

# %% [markdown]
# Now we can call the function like this.

# %%
make_turtle()
square()
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="200.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="75.0" x2="200.0" y2="25.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="25.0" x2="150.0" y2="25.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="25.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# Wrapping a piece of code up in a function is called **encapsulation**.
# One of the benefits of encapsulation is that it attaches a name to the code, which serves as a kind of documentation. Another advantage is that if you re-use the code, it is more concise to call a function twice than to copy and paste the body!
#
# In the current version, the size of the square is always `50`.
# If we want to draw squares with different sizes, we can take the length of the sides as a parameter.

# %%
import jupyturtle
def square(length):
  for i in range(4):
    forward(length)
    left(90)

# %% [markdown]
# Now we can draw squares with different sizes.

# %%
make_turtle()
square(50)
square(100)
square(200)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="200.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="75.0" x2="200.0" y2="25.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="25.0" x2="150.0" y2="25.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="25.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="250.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="250.0" y1="75.0" x2="250.0" y2="-25.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="250.0" y1="-25.0" x2="150.0" y2="-25.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="-25.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="350.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="350.0" y1="75.0" x2="350.0" y2="-125.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="350.0" y1="-125.0" x2="150.0" y2="-125.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="-125.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# Adding a parameter to a function is called **generalization** because it makes the function more general: with the previous version, the square is always the same size; with this version it can be any size.
#
# If we add another parameter, we can make it even more general.
# The following function draws regular polygons with a given number of sides.

# %%
def polygon(n, length):
  angle = 360/n
  for i in range(n):
    forward(length)
    left(angle)

# %% [markdown]
# In a regular polygon with `n` sides, the angle between adjacent sides is `360 / n` degrees.
#
# The following example draws a `7`-sided polygon with side length `30`.

# %%
make_turtle()
polygon(7, 30)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="180.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.0" y1="75.0" x2="198.7" y2="51.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="198.7" y1="51.5" x2="192.0" y2="22.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="192.0" y1="22.3" x2="165.0" y2="9.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="165.0" y1="9.3" x2="138.0" y2="22.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="138.0" y1="22.3" x2="131.3" y2="51.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="131.3" y1="51.5" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(270.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# When a function has more than a few numeric arguments, it is easy to forget what they are, or what order they should be in.
# It can be a good idea to include the names of the parameters in the argument list.

# %%
make_turtle()
polygon(n=7, length=30)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="180.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.0" y1="75.0" x2="198.7" y2="51.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="198.7" y1="51.5" x2="192.0" y2="22.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="192.0" y1="22.3" x2="165.0" y2="9.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="165.0" y1="9.3" x2="138.0" y2="22.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="138.0" y1="22.3" x2="131.3" y2="51.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="131.3" y1="51.5" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(270.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# These are sometimes called "named arguments" because they include the parameter names.
# But in Python they are more often called **keyword arguments** (not to be confused with Python keywords like `for` and `def`).
#
# This use of the assignment operator, `=`, is a reminder about how arguments and parameters work -- when you call a function, the arguments are assigned to the parameters.

# %% [markdown]
# ## Approximating a circle
#
# Now suppose we want to draw a circle.
# We can do that, approximately, by drawing a polygon with a large number of sides, so each side is small enough that it's hard to see.
# Here is a function that uses `polygon` to draw a `30`-sided polygon that approximates a circle.

# %%
import math

def circle(radius):
    circumference = 2 * math.pi * radius
    n = 30
    length = circumference / n
    polygon(n, length)

# %% [markdown]
# `circle` takes the radius of the the circle as a parameter.
# It computes `circumference`, which is the circumference of a circle with the given radius.
# `n` is the number of sides, so `circumference / n` is the length of each side.
#
# This function might take a long time to run.
# We can speed it up by calling `make_turtle` with a keyword argument called `delay` that sets the time, in seconds, the turtle waits after each step.
# The default value is `0.2` seconds -- if we set it to `0.02` it runs about 10 times faster.

# %%
make_turtle(delay=0.02)
circle(30)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="156.3" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="156.3" y1="75.0" x2="162.4" y2="73.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.4" y1="73.7" x2="168.2" y2="71.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="168.2" y1="71.1" x2="173.3" y2="67.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="173.3" y1="67.4" x2="177.5" y2="62.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="177.5" y1="62.8" x2="180.6" y2="57.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.6" y1="57.3" x2="182.5" y2="51.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="182.5" y1="51.4" x2="183.2" y2="45.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="183.2" y1="45.1" x2="182.5" y2="38.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="182.5" y1="38.9" x2="180.6" y2="32.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.6" y1="32.9" x2="177.5" y2="27.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="177.5" y1="27.4" x2="173.3" y2="22.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="173.3" y1="22.8" x2="168.2" y2="19.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="168.2" y1="19.1" x2="162.4" y2="16.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.4" y1="16.5" x2="156.3" y2="15.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="156.3" y1="15.2" x2="150.0" y2="15.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="15.2" x2="143.9" y2="16.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="143.9" y1="16.5" x2="138.1" y2="19.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="138.1" y1="19.1" x2="133.0" y2="22.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="133.0" y1="22.8" x2="128.8" y2="27.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="128.8" y1="27.4" x2="125.7" y2="32.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="125.7" y1="32.9" x2="123.7" y2="38.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="123.7" y1="38.9" x2="123.1" y2="45.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="123.1" y1="45.1" x2="123.7" y2="51.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="123.7" y1="51.4" x2="125.7" y2="57.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="125.7" y1="57.3" x2="128.8" y2="62.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="128.8" y1="62.8" x2="133.0" y2="67.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="133.0" y1="67.4" x2="138.1" y2="71.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="138.1" y1="71.1" x2="143.9" y2="73.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="143.9" y1="73.7" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# A limitation of this solution is that `n` is a constant, which means
# that for very big circles, the sides are too long, and for small
# circles, we waste time drawing very short sides.
# One option is to generalize the function by taking `n` as a parameter.
# But let's keep it simple for now.

# %% [markdown]
# ## Refactoring
#
# Now let's write a more general version of `circle`, called `arc`, that takes a second parameter, `angle`, and draws an arc of a circle that spans the given angle.
# For example, if `angle` is `360` degrees, it draws a complete circle. If `angle` is `180` degrees, it draws a half circle.
#
# To write `circle`, we were able to reuse `polygon`, because a many-sided polygon is a good approximation of a circle.
# But we can't use `polygon` to write `arc`.
#
# Instead, we'll create the more general version of `polygon`, called `polyline`.

# %%
def polyline(n, length, angle):
    for i in range(n):
        forward(length) #Dibuja una linea de cierta longitud
        left(angle) #Gira el lapiz un angulo especifico

# %% [markdown]
# `polyline` takes as parameters the number of line segments to draw, `n`, the length of the segments, `length`, and the angle between them, `angle`.
#
# Now we can rewrite `polygon` to use `polyline`.

# %%
def polygon(n, length):
  angle=360/n #Calcula el angulo para cada giro
  polyline(n, length, angle)

# %% [markdown]
# And we can use `polyline` to write `arc`.

# %%
make_turtle(delay=0.02)
def arc(radius, angle):
    arc_length = 2 * math.pi * radius * angle / 360 #Calcula el perimetro del circulo y luego lo divide por el circulo completo para calcular el trozo que tiene que dibujar
    n = 30 #Constante de lados que polyline tiene que dibujar para que se vea como un circulo medianamente bueno
    length = arc_length / n #Length es la longitud de cada trazada del circulo. Esta se divide por el largo total del arco a dibujar por la cantidad de lados
    step_angle = angle / n #Es el angulo que tiene que doblar para cada trazada. Este se consigue dividiendo el angulo a dibujar por la cantidad de lados
    polyline(n, length, step_angle) #Dibuja un poligono con n=30 lados, la longitud de trazo anteriormente calculada y cada angulo de giro anteriormente calculada
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <g transform="rotate(-90.0,150,75) translate(150, 75)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# `arc` is similar to `circle`, except that it computes `arc_length`, which is a fraction of the circumference of a circle.
#
# Finally, we can rewrite `circle` to use `arc`.

# %%
def circle(radius):
  arc(radius, 360)

# %% [markdown]
# To check that these functions work as expected, we'll use them to draw something like a snail.
# With `delay=0`, the turtle runs as fast as possible.

# %%
make_turtle(delay=0)
polygon(n=20, length=9)
arc(radius=70, angle=70)
circle(radius=10)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="159.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="159.0" y1="75.0" x2="167.6" y2="72.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="167.6" y1="72.2" x2="174.8" y2="66.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="174.8" y1="66.9" x2="180.1" y2="59.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.1" y1="59.6" x2="182.9" y2="51.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="182.9" y1="51.1" x2="182.9" y2="42.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="182.9" y1="42.1" x2="180.1" y2="33.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.1" y1="33.5" x2="174.8" y2="26.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="174.8" y1="26.2" x2="167.6" y2="21.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="167.6" y1="21.0" x2="159.0" y2="18.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="159.0" y1="18.2" x2="150.0" y2="18.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="18.2" x2="141.4" y2="21.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="141.4" y1="21.0" x2="134.2" y2="26.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="134.2" y1="26.2" x2="128.9" y2="33.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="128.9" y1="33.5" x2="126.1" y2="42.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="126.1" y1="42.1" x2="126.1" y2="51.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="126.1" y1="51.1" x2="128.9" y2="59.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="128.9" y1="59.6" x2="134.2" y2="66.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="134.2" y1="66.9" x2="141.4" y2="72.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="141.4" y1="72.2" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="152.9" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="152.9" y1="75.0" x2="155.7" y2="74.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="155.7" y1="74.9" x2="158.5" y2="74.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="158.5" y1="74.7" x2="161.4" y2="74.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="161.4" y1="74.3" x2="164.2" y2="73.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="164.2" y1="73.8" x2="167.0" y2="73.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="167.0" y1="73.3" x2="169.7" y2="72.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="169.7" y1="72.6" x2="172.5" y2="71.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="172.5" y1="71.8" x2="175.2" y2="70.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="175.2" y1="70.9" x2="177.8" y2="69.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="177.8" y1="69.8" x2="180.5" y2="68.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.5" y1="68.7" x2="183.0" y2="67.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="183.0" y1="67.5" x2="185.5" y2="66.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="185.5" y1="66.1" x2="188.0" y2="64.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="188.0" y1="64.7" x2="190.4" y2="63.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="190.4" y1="63.2" x2="192.7" y2="61.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="192.7" y1="61.5" x2="195.0" y2="59.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="195.0" y1="59.8" x2="197.2" y2="58.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="197.2" y1="58.0" x2="199.3" y2="56.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="199.3" y1="56.1" x2="201.4" y2="54.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="201.4" y1="54.1" x2="203.3" y2="52.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="203.3" y1="52.0" x2="205.2" y2="49.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="205.2" y1="49.9" x2="207.0" y2="47.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="207.0" y1="47.6" x2="208.7" y2="45.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="208.7" y1="45.3" x2="210.2" y2="43.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="210.2" y1="43.0" x2="211.7" y2="40.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="211.7" y1="40.5" x2="213.1" y2="38.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="213.1" y1="38.1" x2="214.4" y2="35.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="214.4" y1="35.5" x2="215.6" y2="32.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="215.6" y1="32.9" x2="216.7" y2="30.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="216.7" y1="30.3" x2="217.4" y2="28.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="217.4" y1="28.3" x2="217.7" y2="26.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="217.7" y1="26.2" x2="217.6" y2="24.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="217.6" y1="24.2" x2="217.0" y2="22.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="217.0" y1="22.1" x2="216.0" y2="20.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="216.0" y1="20.3" x2="214.7" y2="18.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="214.7" y1="18.7" x2="213.0" y2="17.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="213.0" y1="17.4" x2="211.1" y2="16.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="211.1" y1="16.5" x2="209.1" y2="16.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="209.1" y1="16.0" x2="207.0" y2="15.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="207.0" y1="15.9" x2="204.9" y2="16.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="204.9" y1="16.3" x2="203.0" y2="17.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="203.0" y1="17.0" x2="201.3" y2="18.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="201.3" y1="18.2" x2="199.8" y2="19.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="199.8" y1="19.7" x2="198.7" y2="21.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="198.7" y1="21.5" x2="198.0" y2="23.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="198.0" y1="23.5" x2="197.7" y2="25.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="197.7" y1="25.5" x2="197.8" y2="27.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="197.8" y1="27.6" x2="198.4" y2="29.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="198.4" y1="29.6" x2="199.4" y2="31.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="199.4" y1="31.5" x2="200.7" y2="33.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.7" y1="33.1" x2="202.4" y2="34.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="202.4" y1="34.4" x2="204.3" y2="35.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="204.3" y1="35.3" x2="206.3" y2="35.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="206.3" y1="35.8" x2="208.4" y2="35.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="208.4" y1="35.9" x2="210.5" y2="35.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="210.5" y1="35.5" x2="212.4" y2="34.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="212.4" y1="34.7" x2="214.1" y2="33.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="214.1" y1="33.6" x2="215.6" y2="32.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="215.6" y1="32.1" x2="216.7" y2="30.3"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(200.0,216.7,30.3) translate(216.7, 30.3)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# In this example, we started with working code and reorganized it with different functions.
# Changes like this, which improve the code without changing its behavior, are called **refactoring**.
#
# If we had planned ahead, we might have written `polyline` first and avoided refactoring, but often you don't know enough at the beginning of a project to design all the functions.
# Once you start coding, you understand the problem better.
# Sometimes refactoring is a sign that you have learned something.

# %% [markdown]
# ## Stack diagram
#
# When we call `circle`, it calls `arc`, which calls `polyline`.
# We can use a stack diagram to show this sequence of function calls and the parameters for each one.

# %%
from diagram import make_binding, make_frame, Frame, Stack

frame1 = make_frame(dict(radius=30), name='circle', loc='left')

frame2 = make_frame(dict(radius=30, angle=360), name='arc', loc='left', dx=1.1)

frame3 = make_frame(dict(n=60, length=3.04, angle=5.8),
                    name='polyline', loc='left', dx=1.1, offsetx=-0.27)

stack = Stack([frame1, frame2, frame3], dy=-0.4)

# %%
from diagram import diagram, adjust

width, height, x, y = [3.58, 1.31, 0.98, 1.06]
ax = diagram(width, height)
bbox = stack.draw(ax, x, y)
#adjust(x, y, bbox)

# %% [markdown]
# Notice that the value of `angle` in `polyline` is different from the value of `angle` in `arc`.
# Parameters are local, which means you can use the same parameter name in different functions; it's a different variable in each function, and it can refer to a different value.

# %% [markdown]
# ## A development plan
#
# A **development plan** is a process for writing programs.
# The process we used in this chapter is "encapsulation and generalization".
# The steps of this process are:
#
# 1.  Start by writing a small program with no function definitions.
#
# 2.  Once you get the program working, identify a coherent piece of it,
#     encapsulate the piece in a function and give it a name.
#
# 3.  Generalize the function by adding appropriate parameters.
#
# 4.  Repeat Steps 1 to 3 until you have a set of working functions.
#
# 5.  Look for opportunities to improve the program by refactoring. For
#     example, if you have similar code in several places, consider
#     factoring it into an appropriately general function.
#
# This process has some drawbacks -- we will see alternatives later -- but it can be useful if you don't know ahead of time how to divide the program into functions.
# This approach lets you design as you go along.

# %% [markdown]
# The design of a function has two parts:
#
# * The **interface** is how the function is used, including its name, the parameters it takes and what the function is supposed to do.
#
# * The **implementation** is how the function does what it's supposed to do.
#
# For example, here's the first version of `circle` we wrote, which uses `polygon`.

# %%
make_turtle(delay=0.02)
polygon(15, 10)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="160.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="160.0" y1="75.0" x2="169.1" y2="70.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="169.1" y1="70.9" x2="175.8" y2="63.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="175.8" y1="63.5" x2="178.9" y2="54.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="178.9" y1="54.0" x2="177.9" y2="44.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="177.9" y1="44.0" x2="172.9" y2="35.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="172.9" y1="35.4" x2="164.8" y2="29.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="164.8" y1="29.5" x2="155.0" y2="27.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="155.0" y1="27.4" x2="145.2" y2="29.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="145.2" y1="29.5" x2="137.1" y2="35.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="137.1" y1="35.4" x2="132.1" y2="44.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="132.1" y1="44.0" x2="131.1" y2="54.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="131.1" y1="54.0" x2="134.2" y2="63.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="134.2" y1="63.5" x2="140.9" y2="70.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="140.9" y1="70.9" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# And here's the refactored version that uses `arc`.

# %%
make_turtle(delay=0.02)
arc(25, 360)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="155.2" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="155.2" y1="75.0" x2="160.4" y2="73.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="160.4" y1="73.9" x2="165.1" y2="71.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="165.1" y1="71.8" x2="169.4" y2="68.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="169.4" y1="68.7" x2="172.9" y2="64.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="172.9" y1="64.8" x2="175.5" y2="60.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="175.5" y1="60.3" x2="177.1" y2="55.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="177.1" y1="55.3" x2="177.7" y2="50.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="177.7" y1="50.1" x2="177.1" y2="44.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="177.1" y1="44.9" x2="175.5" y2="39.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="175.5" y1="39.9" x2="172.9" y2="35.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="172.9" y1="35.4" x2="169.4" y2="31.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="169.4" y1="31.5" x2="165.1" y2="28.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="165.1" y1="28.4" x2="160.4" y2="26.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="160.4" y1="26.3" x2="155.2" y2="25.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="155.2" y1="25.2" x2="150.0" y2="25.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="25.2" x2="144.9" y2="26.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="144.9" y1="26.3" x2="140.1" y2="28.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="140.1" y1="28.4" x2="135.9" y2="31.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="135.9" y1="31.5" x2="132.4" y2="35.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="132.4" y1="35.4" x2="129.7" y2="39.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="129.7" y1="39.9" x2="128.1" y2="44.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="128.1" y1="44.9" x2="127.6" y2="50.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="127.6" y1="50.1" x2="128.1" y2="55.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="128.1" y1="55.3" x2="129.7" y2="60.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="129.7" y1="60.3" x2="132.4" y2="64.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="132.4" y1="64.8" x2="135.9" y2="68.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="135.9" y1="68.7" x2="140.1" y2="71.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="140.1" y1="71.8" x2="144.9" y2="73.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="144.9" y1="73.9" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# These two functions have the same interface -- they take the same parameters and do the same thing -- but they have different implementations.

# %% [markdown]
# ## Docstrings
#
# A **docstring** is a string at the beginning of a function that explains the interface ("doc" is short for "documentation").
# Here is an example:

# %%
def polyline(n, length, angle):
    """Draws line segments with the given length and angle between them.

    n: integer number of line segments
    length: length of the line segments
    angle: angle between segments (in degrees)
    """
    for i in range(n):
        forward(length)
        left(angle)

# %% [markdown]
# By convention, docstrings are triple-quoted strings, also known as **multiline strings** because the triple quotes allow the string to span more than one line.
#
# A docstring should:
#
# * Explain concisely what the function does, without getting into the details of how it works,
#
# * Explain what effect each parameter has on the behavior of the function, and
#
# * Indicate what type each parameter should be, if it is not obvious.
#
# Writing this kind of documentation is an important part of interface design.
# A well-designed interface should be simple to explain; if you have a hard time explaining one of your functions, maybe the interface could be improved.

# %% [markdown]
# ## Debugging
#
# An interface is like a contract between a function and a caller. The
# caller agrees to provide certain arguments and the function agrees to
# do certain work.
#
# For example, `polyline` requires three arguments: `n` has to be an integer; `length` should be a positive number; and `angle` has to be a number, which is understood to be in degrees.
#
# These requirements are called **preconditions** because they are supposed to be true before the function starts executing. Conversely, conditions at the end of the function are **postconditions**.
# Postconditions include the intended effect of the function (like drawing line segments) and any side effects (like moving the turtle or making other changes).
#
# Preconditions are the responsibility of the caller. If the caller violates a precondition and the function doesn't work correctly, the bug is in the caller, not the function.
#
# If the preconditions are satisfied and the postconditions are not, the bug is in the function. If your pre- and postconditions are clear, they can help with debugging.

# %% [markdown]
# ## Glossary
#
# **interface design:**
# A process for designing the interface of a function, which includes the parameters it should take.
#
# **canvas:**
# A window used to display graphical elements including lines, circles, rectangles, and other shapes.
#
# **encapsulation:**
#  The process of transforming a sequence of statements into a function definition.
#
# **generalization:**
#  The process of replacing something unnecessarily specific (like a number) with something appropriately general (like a variable or parameter).
#
# **keyword argument:**
# An argument that includes the name of the parameter.
#
# **refactoring:**
#  The process of modifying a working program to improve function interfaces and other qualities of the code.
#
# **development plan:**
# A process for writing programs.
#
# **docstring:**
#  A string that appears at the top of a function definition to document the function's interface.
#
# **multiline string:**
# A string enclosed in triple quotes that can span more than one line of a program.
#
# **precondition:**
#  A requirement that should be satisfied by the caller before a function starts.
#
# **postcondition:**
#  A requirement that should be satisfied by the function before it ends.

# %% [markdown]
# ## Exercises

# %%
# This cell tells Jupyter to provide detailed debugging information
# when a runtime error occurs. Run it before working on the exercises.

# %xmode Verbose
# Out:
# Exception reporting mode: Verbose

# %% [markdown]
# For the exercises below, there are a few more turtle functions you might want to use.
#
# * `penup` lifts the turtle's imaginary pen so it doesn't leave a trail when it moves.
#
# * `pendown` puts the pen back down.
#
# The following function uses `penup` and `pendown` to move the turtle without leaving a trail.

# %%
from jupyturtle import penup, pendown

def jump(length):
    """Move forward length units without leaving a trail.

    Postcondition: Leaves the pen down.
    """
    penup()
    forward(length)
    pendown()

# %% [markdown]
# ### Exercise
#
# Write a function called `rectangle` that draws a rectangle with given side lengths.
# For example, here's a rectangle that's `80` units wide and `40` units tall.

# %%
def rectangle(wide,length):
  for i in range(2):
    forward(wide)
    left(90)
    forward(length)
    left(90)

# %% [markdown]
# You can use the following code to test your function.

# %%
make_turtle()
rectangle(80,40)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="230.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="230.0" y1="75.0" x2="230.0" y2="35.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="230.0" y1="35.0" x2="150.0" y2="35.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="35.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### Exercise
#
# Write a function called `rhombus` that draws a rhombus with a given side length and a given interior angle. For example, here's a rhombus with side length `50` and an interior angle of `60` degrees.

# %%
def rhombus(length, angle):
  for i in range(2):
    forward(length)
    left(angle)
    forward(length)
    left(180-angle)

# %% [markdown]
# You can use the following code to test your function.

# %%
make_turtle()
rhombus(50, 60)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="200.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="75.0" x2="225.0" y2="31.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="225.0" y1="31.7" x2="175.0" y2="31.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="175.0" y1="31.7" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### Exercise
#
# Now write a more general function called `parallelogram` that draws a quadrilateral with parallel sides. Then rewrite `rectangle` and `rhombus` to use `parallelogram`.

# %%
def parallelogram(length1,length2,angle):
  for i in range(2):
    forward(length1)
    left(angle)
    forward(length2)
    left(180-angle)

# %%
def rectangle(length1,length2):
  parallelogram(length1,length2,90)

# %%
def rhombus(length1, angle):
  parallelogram(length1,length1,angle)

# %% [markdown]
# You can use the following code to test your functions.

# %%
make_turtle(delay=0.01)
rectangle(60,10)
rhombus(50,30)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="210.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="210.0" y1="75.0" x2="210.0" y2="65.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="210.0" y1="65.0" x2="150.0" y2="65.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="65.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="200.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="75.0" x2="243.3" y2="50.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="243.3" y1="50.0" x2="193.3" y2="50.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="193.3" y1="50.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### Exercise
#
# Write an appropriately general set of functions that can draw shapes like this.
#
# ![](https://github.com/AllenDowney/ThinkPython/raw/v3/jupyturtle_pie.png)
#
# Hint: Write a function called `triangle` that draws one triangular segment, and then a function called `draw_pie` that uses `triangle`.

# %%
def triangle(radius,  angle):
    y = 2 *(radius * math.sin(angle * math.pi / 180))
    right(angle)
    forward(radius)
    left(90+angle)
    forward(y)
    left(90+angle)
    forward(radius)
    left(180-angle)

# %%
def draw_pie(n, radius):
    angle = 360 / n
    for i in range(n):
        triangle(radius,  angle/2)
        left(angle)

# %% [markdown]
# You can use the following code to test your functions.

# %%
make_turtle(delay=0.01, width=500, height=500)
draw_pie(15,100)
# Out:
# <svg width="500" height="500">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="250" y1="250" x2="347.8" y2="270.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="347.8" y1="270.8" x2="347.8" y2="229.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="347.8" y1="229.2" x2="250.0" y2="250.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="250.0" y1="250.0" x2="347.8" y2="229.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="347.8" y1="229.2" x2="330.9" y2="191.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="330.9" y1="191.2" x2="250.0" y2="250.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="250.0" y1="250.0" x2="330.9" y2="191.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="330.9" y1="191.2" x2="300.0" y2="163.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="300.0" y1="163.4" x2="250.0" y2="250.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="250.0" y1="250.0" x2="300.0" y2="163.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="300.0" y1="163.4" x2="260.5" y2="150.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="260.5" y1="150.5" x2="250.0" y2="250.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="250.0" y1="250.0" x2="260.5" y2="150.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="260.5" y1="150.5" x2="219.1" y2="154.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="219.1" y1="154.9" x2="250.0" y2="250.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="250.0" y1="250.0" x2="219.1" y2="154.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="219.1" y1="154.9" x2="183.1" y2="175.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="183.1" y1="175.7" x2="250.0" y2="250.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="250.0" y1="250.0" x2="183.1" y2="175.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="183.1" y1="175.7" x2="158.6" y2="209.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="158.6" y1="209.3" x2="250.0" y2="250.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="250.0" y1="250.0" x2="158.6" y2="209.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="158.6" y1="209.3" x2="150.0" y2="250.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="250.0" x2="250.0" y2="250.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="250.0" y1="250.0" x2="150.0" y2="250.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="250.0" x2="158.6" y2="290.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="158.6" y1="290.7" x2="250.0" y2="250.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="250.0" y1="250.0" x2="158.6" y2="290.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="158.6" y1="290.7" x2="183.1" y2="324.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="183.1" y1="324.3" x2="250.0" y2="250.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="250.0" y1="250.0" x2="183.1" y2="324.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="183.1" y1="324.3" x2="219.1" y2="345.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="219.1" y1="345.1" x2="250.0" y2="250.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="250.0" y1="250.0" x2="219.1" y2="345.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="219.1" y1="345.1" x2="260.5" y2="349.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="260.5" y1="349.5" x2="250.0" y2="250.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="250.0" y1="250.0" x2="260.5" y2="349.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="260.5" y1="349.5" x2="300.0" y2="336.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="300.0" y1="336.6" x2="250.0" y2="250.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="250.0" y1="250.0" x2="300.0" y2="336.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="300.0" y1="336.6" x2="330.9" y2="308.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="330.9" y1="308.8" x2="250.0" y2="250.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="250.0" y1="250.0" x2="330.9" y2="308.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="330.9" y1="308.8" x2="347.8" y2="270.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="347.8" y1="270.8" x2="250.0" y2="250.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,250.0,250.0) translate(250.0, 250.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### Exercise
#
# Write an appropriately general set of functions that can draw flowers like this.
#
# ![](https://github.com/AllenDowney/ThinkPython/raw/v3/jupyturtle_flower.png)
#
# Hint: Use `arc` to write a function called `petal` that draws one flower petal.

# %%
def petal(radius, angle, petals):
  for f in range(petals):
    for i in range(2):
      arc(radius, angle)
      left(180-angle)
    left(360/petals)

# %%
make_turtle(delay=0.0002, width=900, height=500)
petal(100,90,9)
penup()
forward(-300)
pendown()
petal(150,60,7)
# Out:
# <svg width="900" height="500">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="450" y1="250" x2="455.2" y2="250.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="455.2" y1="250.0" x2="460.5" y2="249.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="460.5" y1="249.7" x2="465.7" y2="249.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="465.7" y1="249.2" x2="470.8" y2="248.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="470.8" y1="248.4" x2="476.0" y2="247.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="476.0" y1="247.3" x2="481.0" y2="245.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="481.0" y1="245.9" x2="486.0" y2="244.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="486.0" y1="244.3" x2="490.9" y2="242.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="490.9" y1="242.4" x2="495.7" y2="240.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="495.7" y1="240.3" x2="500.3" y2="237.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="500.3" y1="237.9" x2="504.9" y2="235.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="504.9" y1="235.3" x2="509.3" y2="232.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="509.3" y1="232.4" x2="513.5" y2="229.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="513.5" y1="229.4" x2="517.6" y2="226.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="517.6" y1="226.1" x2="521.5" y2="222.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="521.5" y1="222.6" x2="525.2" y2="218.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="525.2" y1="218.9" x2="528.7" y2="215.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="528.7" y1="215.0" x2="532.0" y2="210.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="532.0" y1="210.9" x2="535.0" y2="206.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="535.0" y1="206.7" x2="537.9" y2="202.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="537.9" y1="202.3" x2="540.5" y2="197.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="540.5" y1="197.7" x2="542.9" y2="193.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="542.9" y1="193.1" x2="545.0" y2="188.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="545.0" y1="188.3" x2="546.9" y2="183.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="546.9" y1="183.4" x2="548.5" y2="178.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="548.5" y1="178.4" x2="549.9" y2="173.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="549.9" y1="173.4" x2="551.0" y2="168.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="551.0" y1="168.2" x2="551.8" y2="163.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="551.8" y1="163.1" x2="552.3" y2="157.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="552.3" y1="157.9" x2="552.6" y2="152.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="552.6" y1="152.6" x2="547.4" y2="152.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="547.4" y1="152.6" x2="542.1" y2="152.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="542.1" y1="152.9" x2="536.9" y2="153.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="536.9" y1="153.5" x2="531.8" y2="154.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="531.8" y1="154.3" x2="526.6" y2="155.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="526.6" y1="155.4" x2="521.6" y2="156.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="521.6" y1="156.7" x2="516.6" y2="158.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="516.6" y1="158.3" x2="511.7" y2="160.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="511.7" y1="160.2" x2="506.9" y2="162.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="506.9" y1="162.3" x2="502.3" y2="164.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="502.3" y1="164.7" x2="497.7" y2="167.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="497.7" y1="167.3" x2="493.3" y2="170.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="493.3" y1="170.2" x2="489.1" y2="173.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="489.1" y1="173.3" x2="485.0" y2="176.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="485.0" y1="176.6" x2="481.1" y2="180.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="481.1" y1="180.1" x2="477.4" y2="183.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="477.4" y1="183.8" x2="473.9" y2="187.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="473.9" y1="187.7" x2="470.6" y2="191.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="470.6" y1="191.7" x2="467.6" y2="196.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="467.6" y1="196.0" x2="464.7" y2="200.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="464.7" y1="200.4" x2="462.1" y2="204.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="462.1" y1="204.9" x2="459.7" y2="209.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="459.7" y1="209.6" x2="457.6" y2="214.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="457.6" y1="214.3" x2="455.7" y2="219.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="455.7" y1="219.2" x2="454.1" y2="224.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="454.1" y1="224.2" x2="452.7" y2="229.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="452.7" y1="229.3" x2="451.6" y2="234.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="451.6" y1="234.4" x2="450.8" y2="239.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="450.8" y1="239.6" x2="450.3" y2="244.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="450.3" y1="244.8" x2="450.0" y2="250.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="450.0" y1="250.0" x2="454.0" y2="246.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="454.0" y1="246.6" x2="457.8" y2="243.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="457.8" y1="243.1" x2="461.5" y2="239.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="461.5" y1="239.3" x2="464.9" y2="235.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="464.9" y1="235.3" x2="468.1" y2="231.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="468.1" y1="231.2" x2="471.1" y2="226.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="471.1" y1="226.9" x2="473.9" y2="222.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="473.9" y1="222.5" x2="476.5" y2="217.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="476.5" y1="217.9" x2="478.7" y2="213.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="478.7" y1="213.2" x2="480.8" y2="208.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="480.8" y1="208.4" x2="482.6" y2="203.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="482.6" y1="203.5" x2="484.1" y2="198.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="484.1" y1="198.5" x2="485.4" y2="193.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="485.4" y1="193.4" x2="486.4" y2="188.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="486.4" y1="188.2" x2="487.1" y2="183.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="487.1" y1="183.1" x2="487.6" y2="177.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="487.6" y1="177.8" x2="487.7" y2="172.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="487.7" y1="172.6" x2="487.7" y2="167.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="487.7" y1="167.4" x2="487.3" y2="162.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="487.3" y1="162.1" x2="486.7" y2="156.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="486.7" y1="156.9" x2="485.7" y2="151.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="485.7" y1="151.8" x2="484.6" y2="146.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="484.6" y1="146.7" x2="483.1" y2="141.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="483.1" y1="141.7" x2="481.4" y2="136.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="481.4" y1="136.7" x2="479.5" y2="131.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="479.5" y1="131.9" x2="477.2" y2="127.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="477.2" y1="127.1" x2="474.8" y2="122.5"
#     stroke="#663399" stroke-width="2" />

# %% [markdown]
# You can use the following code to test your functions.
#
# Because the solution draws a lot of small line segments, it tends to slow down as it runs.
# To avoid that, you can add the keyword argument `auto_render=False` to avoid drawing after every step, and then call the `render` function at the end to show the result.
#
# While you are debugging, you might want to remove `auto_render=False`.

# %%
from jupyturtle import render
make_turtle(width=900, height=500, auto_render=False)
petal(100,90,30)
penup()
forward(-300)
pendown()
petal(150,60,50)
render()
# Out:
# <svg width="900" height="500">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="450" y1="250" x2="455.2" y2="250.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="455.2" y1="250.0" x2="460.5" y2="249.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="460.5" y1="249.7" x2="465.7" y2="249.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="465.7" y1="249.2" x2="470.8" y2="248.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="470.8" y1="248.4" x2="476.0" y2="247.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="476.0" y1="247.3" x2="481.0" y2="245.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="481.0" y1="245.9" x2="486.0" y2="244.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="486.0" y1="244.3" x2="490.9" y2="242.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="490.9" y1="242.4" x2="495.7" y2="240.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="495.7" y1="240.3" x2="500.3" y2="237.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="500.3" y1="237.9" x2="504.9" y2="235.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="504.9" y1="235.3" x2="509.3" y2="232.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="509.3" y1="232.4" x2="513.5" y2="229.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="513.5" y1="229.4" x2="517.6" y2="226.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="517.6" y1="226.1" x2="521.5" y2="222.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="521.5" y1="222.6" x2="525.2" y2="218.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="525.2" y1="218.9" x2="528.7" y2="215.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="528.7" y1="215.0" x2="532.0" y2="210.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="532.0" y1="210.9" x2="535.0" y2="206.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="535.0" y1="206.7" x2="537.9" y2="202.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="537.9" y1="202.3" x2="540.5" y2="197.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="540.5" y1="197.7" x2="542.9" y2="193.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="542.9" y1="193.1" x2="545.0" y2="188.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="545.0" y1="188.3" x2="546.9" y2="183.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="546.9" y1="183.4" x2="548.5" y2="178.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="548.5" y1="178.4" x2="549.9" y2="173.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="549.9" y1="173.4" x2="551.0" y2="168.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="551.0" y1="168.2" x2="551.8" y2="163.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="551.8" y1="163.1" x2="552.3" y2="157.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="552.3" y1="157.9" x2="552.6" y2="152.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="552.6" y1="152.6" x2="547.4" y2="152.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="547.4" y1="152.6" x2="542.1" y2="152.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="542.1" y1="152.9" x2="536.9" y2="153.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="536.9" y1="153.5" x2="531.8" y2="154.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="531.8" y1="154.3" x2="526.6" y2="155.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="526.6" y1="155.4" x2="521.6" y2="156.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="521.6" y1="156.7" x2="516.6" y2="158.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="516.6" y1="158.3" x2="511.7" y2="160.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="511.7" y1="160.2" x2="506.9" y2="162.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="506.9" y1="162.3" x2="502.3" y2="164.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="502.3" y1="164.7" x2="497.7" y2="167.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="497.7" y1="167.3" x2="493.3" y2="170.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="493.3" y1="170.2" x2="489.1" y2="173.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="489.1" y1="173.3" x2="485.0" y2="176.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="485.0" y1="176.6" x2="481.1" y2="180.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="481.1" y1="180.1" x2="477.4" y2="183.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="477.4" y1="183.8" x2="473.9" y2="187.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="473.9" y1="187.7" x2="470.6" y2="191.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="470.6" y1="191.7" x2="467.6" y2="196.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="467.6" y1="196.0" x2="464.7" y2="200.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="464.7" y1="200.4" x2="462.1" y2="204.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="462.1" y1="204.9" x2="459.7" y2="209.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="459.7" y1="209.6" x2="457.6" y2="214.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="457.6" y1="214.3" x2="455.7" y2="219.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="455.7" y1="219.2" x2="454.1" y2="224.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="454.1" y1="224.2" x2="452.7" y2="229.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="452.7" y1="229.3" x2="451.6" y2="234.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="451.6" y1="234.4" x2="450.8" y2="239.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="450.8" y1="239.6" x2="450.3" y2="244.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="450.3" y1="244.8" x2="450.0" y2="250.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="450.0" y1="250.0" x2="455.1" y2="248.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="455.1" y1="248.9" x2="460.2" y2="247.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="460.2" y1="247.6" x2="465.2" y2="245.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="465.2" y1="245.9" x2="470.0" y2="244.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="470.0" y1="244.1" x2="474.8" y2="241.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="474.8" y1="241.9" x2="479.5" y2="239.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="479.5" y1="239.6" x2="484.0" y2="236.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="484.0" y1="236.9" x2="488.4" y2="234.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="488.4" y1="234.1" x2="492.7" y2="231.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="492.7" y1="231.0" x2="496.7" y2="227.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="496.7" y1="227.7" x2="500.6" y2="224.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="500.6" y1="224.2" x2="504.3" y2="220.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="504.3" y1="220.5" x2="507.8" y2="216.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="507.8" y1="216.6" x2="511.1" y2="212.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="511.1" y1="212.5" x2="514.2" y2="208.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="514.2" y1="208.3" x2="517.0" y2="203.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="517.0" y1="203.9" x2="519.7" y2="199.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="519.7" y1="199.4" x2="522.0" y2="194.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="522.0" y1="194.7" x2="524.2" y2="189.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="524.2" y1="189.9" x2="526.0" y2="185.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="526.0" y1="185.0" x2="527.7" y2="180.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="527.7" y1="180.1" x2="529.0" y2="175.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="529.0" y1="175.0" x2="530.1" y2="169.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="530.1" y1="169.9" x2="530.9" y2="164.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="530.9" y1="164.7" x2="531.5" y2="159.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="531.5" y1="159.5" x2="531.8" y2="154.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="531.8" y1="154.3" x2="531.8" y2="149.0"
#     stroke="#663399" stroke-width="2" />

# %% [markdown]
# ### Ask a virtual assistant
#
# There are several modules like `jupyturtle` in Python, and the one we used in this chapter has been customized for this book.
# So if you ask a virtual assistant for help, it won't know which module to use.
# But if you give it a few examples to work with, it can probably figure it out.
# For example, try this prompt and see if it can write a function that draws a spiral:
#
# ```
# The following program uses a turtle graphics module to draw a circle:
#
# from jupyturtle import make_turtle, forward, left
# import math
#
# def polygon(n, length):
#     angle = 360 / n
#     for i in range(n):
#         forward(length)
#         left(angle)
#
# def circle(radius):
#     circumference = 2 * math.pi * radius
#     n = 30
#     length = circumference / n
#     polygon(n, length)
#
# make_turtle(delay=0)
# circle(30)
#
# Write a function that draws a spiral.
# ```

# %% [markdown]
# Keep in mind that the result might use features we have not seen yet, and it might have errors.
# Copy the code from the VA and see if you can get it working.
# If you didn't get what you wanted, try modifying the prompt.

# %%
import math

def spiral(length, angle):
    turtle = make_turtle(delay=0.01)
    for _ in range(100):
        forward(length)
        right(angle)
        length += 1

spiral(5, 90)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="155.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="155.0" y1="75.0" x2="155.0" y2="81.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="155.0" y1="81.0" x2="148.0" y2="81.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="148.0" y1="81.0" x2="148.0" y2="73.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="148.0" y1="73.0" x2="157.0" y2="73.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="157.0" y1="73.0" x2="157.0" y2="83.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="157.0" y1="83.0" x2="146.0" y2="83.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="146.0" y1="83.0" x2="146.0" y2="71.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="146.0" y1="71.0" x2="159.0" y2="71.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="159.0" y1="71.0" x2="159.0" y2="85.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="159.0" y1="85.0" x2="144.0" y2="85.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="144.0" y1="85.0" x2="144.0" y2="69.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="144.0" y1="69.0" x2="161.0" y2="69.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="161.0" y1="69.0" x2="161.0" y2="87.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="161.0" y1="87.0" x2="142.0" y2="87.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="142.0" y1="87.0" x2="142.0" y2="67.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="142.0" y1="67.0" x2="163.0" y2="67.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="163.0" y1="67.0" x2="163.0" y2="89.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="163.0" y1="89.0" x2="140.0" y2="89.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="140.0" y1="89.0" x2="140.0" y2="65.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="140.0" y1="65.0" x2="165.0" y2="65.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="165.0" y1="65.0" x2="165.0" y2="91.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="165.0" y1="91.0" x2="138.0" y2="91.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="138.0" y1="91.0" x2="138.0" y2="63.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="138.0" y1="63.0" x2="167.0" y2="63.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="167.0" y1="63.0" x2="167.0" y2="93.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="167.0" y1="93.0" x2="136.0" y2="93.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="136.0" y1="93.0" x2="136.0" y2="61.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="136.0" y1="61.0" x2="169.0" y2="61.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="169.0" y1="61.0" x2="169.0" y2="95.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="169.0" y1="95.0" x2="134.0" y2="95.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="134.0" y1="95.0" x2="134.0" y2="59.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="134.0" y1="59.0" x2="171.0" y2="59.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="171.0" y1="59.0" x2="171.0" y2="97.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="171.0" y1="97.0" x2="132.0" y2="97.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="132.0" y1="97.0" x2="132.0" y2="57.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="132.0" y1="57.0" x2="173.0" y2="57.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="173.0" y1="57.0" x2="173.0" y2="99.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="173.0" y1="99.0" x2="130.0" y2="99.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="130.0" y1="99.0" x2="130.0" y2="55.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="130.0" y1="55.0" x2="175.0" y2="55.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="175.0" y1="55.0" x2="175.0" y2="101.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="175.0" y1="101.0" x2="128.0" y2="101.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="128.0" y1="101.0" x2="128.0" y2="53.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="128.0" y1="53.0" x2="177.0" y2="53.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="177.0" y1="53.0" x2="177.0" y2="103.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="177.0" y1="103.0" x2="126.0" y2="103.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="126.0" y1="103.0" x2="126.0" y2="51.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="126.0" y1="51.0" x2="179.0" y2="51.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="179.0" y1="51.0" x2="179.0" y2="105.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="179.0" y1="105.0" x2="124.0" y2="105.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="124.0" y1="105.0" x2="124.0" y2="49.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="124.0" y1="49.0" x2="181.0" y2="49.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="181.0" y1="49.0" x2="181.0" y2="107.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="181.0" y1="107.0" x2="122.0" y2="107.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="122.0" y1="107.0" x2="122.0" y2="47.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="122.0" y1="47.0" x2="183.0" y2="47.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="183.0" y1="47.0" x2="183.0" y2="109.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="183.0" y1="109.0" x2="120.0" y2="109.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="120.0" y1="109.0" x2="120.0" y2="45.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="120.0" y1="45.0" x2="185.0" y2="45.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="185.0" y1="45.0" x2="185.0" y2="111.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="185.0" y1="111.0" x2="118.0" y2="111.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="118.0" y1="111.0" x2="118.0" y2="43.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="118.0" y1="43.0" x2="187.0" y2="43.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="187.0" y1="43.0" x2="187.0" y2="113.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="187.0" y1="113.0" x2="116.0" y2="113.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="116.0" y1="113.0" x2="116.0" y2="41.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="116.0" y1="41.0" x2="189.0" y2="41.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="189.0" y1="41.0" x2="189.0" y2="115.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="189.0" y1="115.0" x2="114.0" y2="115.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="114.0" y1="115.0" x2="114.0" y2="39.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="114.0" y1="39.0" x2="191.0" y2="39.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="191.0" y1="39.0" x2="191.0" y2="117.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="191.0" y1="117.0" x2="112.0" y2="117.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="112.0" y1="117.0" x2="112.0" y2="37.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="112.0" y1="37.0" x2="193.0" y2="37.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="193.0" y1="37.0" x2="193.0" y2="119.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="193.0" y1="119.0" x2="110.0" y2="119.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="110.0" y1="119.0" x2="110.0" y2="35.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="110.0" y1="35.0" x2="195.0" y2="35.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="195.0" y1="35.0" x2="195.0" y2="121.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="195.0" y1="121.0" x2="108.0" y2="121.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="108.0" y1="121.0" x2="108.0" y2="33.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="108.0" y1="33.0" x2="197.0" y2="33.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="197.0" y1="33.0" x2="197.0" y2="123.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="197.0" y1="123.0" x2="106.0" y2="123.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="106.0" y1="123.0" x2="106.0" y2="31.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="106.0" y1="31.0" x2="199.0"
# <svg width="500" height="500">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="250" y1="250" x2="250.9" y2="250.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="250.9" y1="250.0" x2="251.7" y2="250.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="251.7" y1="250.0" x2="252.6" y2="250.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="252.6" y1="250.0" x2="253.5" y2="249.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="253.5" y1="249.9" x2="254.4" y2="249.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="254.4" y1="249.8" x2="255.3" y2="249.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="255.3" y1="249.8" x2="256.1" y2="249.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="256.1" y1="249.7" x2="257.0" y2="249.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="257.0" y1="249.6" x2="257.9" y2="249.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="257.9" y1="249.4" x2="258.8" y2="249.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="258.8" y1="249.3" x2="259.6" y2="249.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="259.6" y1="249.2" x2="260.5" y2="249.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="260.5" y1="249.0" x2="261.4" y2="248.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="261.4" y1="248.8" x2="262.3" y2="248.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="262.3" y1="248.6" x2="263.1" y2="248.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="263.1" y1="248.4" x2="264.0" y2="248.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="264.0" y1="248.1" x2="264.9" y2="247.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="264.9" y1="247.9" x2="265.7" y2="247.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="265.7" y1="247.6" x2="266.6" y2="247.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="266.6" y1="247.4" x2="267.4" y2="247.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="267.4" y1="247.1" x2="268.3" y2="246.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="268.3" y1="246.7" x2="269.2" y2="246.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="269.2" y1="246.4" x2="270.0" y2="246.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="270.0" y1="246.1" x2="270.8" y2="245.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="270.8" y1="245.7" x2="271.7" y2="245.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="271.7" y1="245.4" x2="272.5" y2="245.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="272.5" y1="245.0" x2="273.3" y2="244.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="273.3" y1="244.6" x2="274.1" y2="244.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="274.1" y1="244.1" x2="275.0" y2="243.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="275.0" y1="243.7" x2="275.8" y2="243.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="275.8" y1="243.3" x2="276.6" y2="242.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="276.6" y1="242.8" x2="277.4" y2="242.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="277.4" y1="242.3" x2="278.2" y2="241.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="278.2" y1="241.8" x2="278.9" y2="241.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="278.9" y1="241.3" x2="279.7" y2="240.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="279.7" y1="240.8" x2="280.5" y2="240.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="280.5" y1="240.3" x2="281.2" y2="239.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="281.2" y1="239.7" x2="282.0" y2="239.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="282.0" y1="239.2" x2="282.7" y2="238.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="282.7" y1="238.6" x2="283.4" y2="238.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="283.4" y1="238.0" x2="284.2" y2="237.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="284.2" y1="237.4" x2="284.9" y2="236.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="284.9" y1="236.8" x2="285.6" y2="236.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="285.6" y1="236.1" x2="286.3" y2="235.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="286.3" y1="235.5" x2="287.0" y2="234.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="287.0" y1="234.8" x2="287.6" y2="234.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="287.6" y1="234.1" x2="288.3" y2="233.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="288.3" y1="233.5" x2="288.9" y2="232.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="288.9" y1="232.8" x2="289.6" y2="232.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="289.6" y1="232.1" x2="290.2" y2="231.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="290.2" y1="231.3" x2="290.8" y2="230.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="290.8" y1="230.6" x2="291.4" y2="229.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="291.4" y1="229.8" x2="292.0" y2="229.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="292.0" y1="229.1" x2="292.6" y2="228.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="292.6" y1="228.3" x2="293.2" y2="227.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="293.2" y1="227.5" x2="293.7" y2="226.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="293.7" y1="226.7" x2="294.3" y2="225.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="294.3" y1="225.9" x2="294.8" y2="225.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="294.8" y1="225.1" x2="295.3" y2="224.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="295.3" y1="224.3" x2="295.8" y2="223.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="295.8" y1="223.5" x2="296.3" y2="222.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="296.3" y1="222.6" x2="296.8" y2="221.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="296.8" y1="221.8" x2="297.2" y2="220.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="297.2" y1="220.9" x2="297.7" y2="220.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="297.7" y1="220.0" x2="298.1" y2="219.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="298.1" y1="219.1" x2="298.5" y2="218.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="298.5" y1="218.2" x2="298.9" y2="217.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="298.9" y1="217.3" x2="299.3" y2="216.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="299.3" y1="216.4" x2="299.7" y2="215.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="299.7" y1="215.5" x2="300.1" y2="214.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="300.1" y1="214.6" x2="300.4" y2="213.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="300.4" y1="213.6" x2="300.7" y2="212.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="300.7" y1="212.7" x2="301.0" y2="211.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="301.0" y1="211.8" x2="301.3" y2="210.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="301.3" y1="210.8" x2="301.6" y2="209.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="301.6" y1="209.8" x2="301.9" y2="208.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="301.9" y1="208.9" x2="302.1" y2="207.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="302.1" y1="207.9" x2="302.3" y2="206.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="302.3" y1="206.9" x2="302.5" y2="205.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="302.5" y1="205.9" x2="302.7" y2="204.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="302.7" y1="204.9" x2="302.9" y2="203.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="302.9" y1="203.9" x2="303.1" y2="202.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="303.1" y1="202.9" x2="303.2" y2="201.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="303.2" y1="201.9" x2="303.3" y2="200.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="303.3" y1="200.9" x2="303.4" y2="199.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="303.4" y1="199.9" x2="303.5" y2="198.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="303.5" y1="198.9" x2="303.6" y2="197.9"
#     stroke="#663399" stroke-width="2" />

# %%
def circular_spiral(radius, angle):
    make_turtle(auto_render=False, width=500, height=500)
    rotations = 5
    distance = 2 * math.pi * radius / 360
    for _ in range(rotations * 360):
        forward(distance)
        left(angle)
        radius += 0.1
        distance = 2 * math.pi * radius / 360
    render()
circular_spiral(50, 1)
# Out:
# <svg width="500" height="500">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="250" y1="250" x2="250.9" y2="250.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="250.9" y1="250.0" x2="251.7" y2="250.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="251.7" y1="250.0" x2="252.6" y2="250.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="252.6" y1="250.0" x2="253.5" y2="249.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="253.5" y1="249.9" x2="254.4" y2="249.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="254.4" y1="249.8" x2="255.3" y2="249.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="255.3" y1="249.8" x2="256.1" y2="249.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="256.1" y1="249.7" x2="257.0" y2="249.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="257.0" y1="249.6" x2="257.9" y2="249.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="257.9" y1="249.4" x2="258.8" y2="249.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="258.8" y1="249.3" x2="259.6" y2="249.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="259.6" y1="249.2" x2="260.5" y2="249.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="260.5" y1="249.0" x2="261.4" y2="248.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="261.4" y1="248.8" x2="262.3" y2="248.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="262.3" y1="248.6" x2="263.1" y2="248.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="263.1" y1="248.4" x2="264.0" y2="248.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="264.0" y1="248.1" x2="264.9" y2="247.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="264.9" y1="247.9" x2="265.7" y2="247.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="265.7" y1="247.6" x2="266.6" y2="247.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="266.6" y1="247.4" x2="267.4" y2="247.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="267.4" y1="247.1" x2="268.3" y2="246.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="268.3" y1="246.7" x2="269.2" y2="246.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="269.2" y1="246.4" x2="270.0" y2="246.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="270.0" y1="246.1" x2="270.8" y2="245.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="270.8" y1="245.7" x2="271.7" y2="245.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="271.7" y1="245.4" x2="272.5" y2="245.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="272.5" y1="245.0" x2="273.3" y2="244.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="273.3" y1="244.6" x2="274.1" y2="244.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="274.1" y1="244.1" x2="275.0" y2="243.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="275.0" y1="243.7" x2="275.8" y2="243.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="275.8" y1="243.3" x2="276.6" y2="242.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="276.6" y1="242.8" x2="277.4" y2="242.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="277.4" y1="242.3" x2="278.2" y2="241.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="278.2" y1="241.8" x2="278.9" y2="241.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="278.9" y1="241.3" x2="279.7" y2="240.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="279.7" y1="240.8" x2="280.5" y2="240.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="280.5" y1="240.3" x2="281.2" y2="239.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="281.2" y1="239.7" x2="282.0" y2="239.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="282.0" y1="239.2" x2="282.7" y2="238.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="282.7" y1="238.6" x2="283.4" y2="238.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="283.4" y1="238.0" x2="284.2" y2="237.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="284.2" y1="237.4" x2="284.9" y2="236.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="284.9" y1="236.8" x2="285.6" y2="236.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="285.6" y1="236.1" x2="286.3" y2="235.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="286.3" y1="235.5" x2="287.0" y2="234.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="287.0" y1="234.8" x2="287.6" y2="234.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="287.6" y1="234.1" x2="288.3" y2="233.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="288.3" y1="233.5" x2="288.9" y2="232.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="288.9" y1="232.8" x2="289.6" y2="232.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="289.6" y1="232.1" x2="290.2" y2="231.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="290.2" y1="231.3" x2="290.8" y2="230.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="290.8" y1="230.6" x2="291.4" y2="229.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="291.4" y1="229.8" x2="292.0" y2="229.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="292.0" y1="229.1" x2="292.6" y2="228.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="292.6" y1="228.3" x2="293.2" y2="227.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="293.2" y1="227.5" x2="293.7" y2="226.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="293.7" y1="226.7" x2="294.3" y2="225.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="294.3" y1="225.9" x2="294.8" y2="225.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="294.8" y1="225.1" x2="295.3" y2="224.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="295.3" y1="224.3" x2="295.8" y2="223.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="295.8" y1="223.5" x2="296.3" y2="222.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="296.3" y1="222.6" x2="296.8" y2="221.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="296.8" y1="221.8" x2="297.2" y2="220.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="297.2" y1="220.9" x2="297.7" y2="220.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="297.7" y1="220.0" x2="298.1" y2="219.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="298.1" y1="219.1" x2="298.5" y2="218.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="298.5" y1="218.2" x2="298.9" y2="217.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="298.9" y1="217.3" x2="299.3" y2="216.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="299.3" y1="216.4" x2="299.7" y2="215.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="299.7" y1="215.5" x2="300.1" y2="214.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="300.1" y1="214.6" x2="300.4" y2="213.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="300.4" y1="213.6" x2="300.7" y2="212.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="300.7" y1="212.7" x2="301.0" y2="211.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="301.0" y1="211.8" x2="301.3" y2="210.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="301.3" y1="210.8" x2="301.6" y2="209.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="301.6" y1="209.8" x2="301.9" y2="208.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="301.9" y1="208.9" x2="302.1" y2="207.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="302.1" y1="207.9" x2="302.3" y2="206.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="302.3" y1="206.9" x2="302.5" y2="205.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="302.5" y1="205.9" x2="302.7" y2="204.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="302.7" y1="204.9" x2="302.9" y2="203.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="302.9" y1="203.9" x2="303.1" y2="202.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="303.1" y1="202.9" x2="303.2" y2="201.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="303.2" y1="201.9" x2="303.3" y2="200.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="303.3" y1="200.9" x2="303.4" y2="199.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="303.4" y1="199.9" x2="303.5" y2="198.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="303.5" y1="198.9" x2="303.6" y2="197.9"
#     stroke="#663399" stroke-width="2" />

# %% [markdown]
# [Think Python: 3rd Edition](https://allendowney.github.io/ThinkPython/index.html)
#
# Copyright 2024 [Allen B. Downey](https://allendowney.com)
#
# Code license: [MIT License](https://mit-license.org/)
#
# Text license: [Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International](https://creativecommons.org/licenses/by-nc-sa/4.0/)
